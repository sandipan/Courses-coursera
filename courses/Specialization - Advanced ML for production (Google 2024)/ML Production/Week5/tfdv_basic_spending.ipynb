# %% [markdown]
# # Introduction to TensorFlow Data Validation
#
#
# ## Learning objectives
#
# 1. Review TFDV methods.
# 2. Generate statistics.
# 3. Visualize statistics.
# 4. Infer a schema.
# 5. Update a schema.
#
#
#
# ## Introduction
# This lab is an introduction to TensorFlow Data Validation (TFDV), a key component of TensorFlow Extended.  This lab serves as a foundation for understanding the features of TFDV and how it can help you understand, validate, and monitor your data.
#
# TFDV can be used for generating schemas and statistics about the distribution of every feature in the dataset. Such information is useful for comparing multiple datasets (e.g. training vs inference datasets) and reporting:
#
# Statistical differences in the features distribution
# TFDV also offers visualization capabilities for comparing datasets based on the Google PAIR Facets project.
#
# Each learning objective will correspond to a __#TODO__ in the [student lab notebook](../labs/tfdv_basic_spending.ipynb) -- try to complete that notebook first before reviewing this solution notebook.

# %% [markdown]
# ### Import Libraries

# %%
# !pip install pyarrow
# !pip install numpy
# !pip install tensorflow-data-validation --user
# Out:
# Requirement already satisfied: pyarrow in /home/jupyter/.local/lib/python3.9/site-packages (10.0.1)
# Requirement already satisfied: numpy>=1.16.6 in /home/jupyter/.local/lib/python3.9/site-packages (from pyarrow) (1.26.4)
# Requirement already satisfied: numpy in /home/jupyter/.local/lib/python3.9/site-packages (1.26.4)
# Requirement already satisfied: tensorflow-data-validation in /home/jupyter/.local/lib/python3.9/site-packages (1.15.1)
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow-data-validation) (1.4.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow-data-validation) (1.4.0)
# Requirement already satisfied: numpy>=1.22.0 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow-data-validation) (1.26.4)
# Requirement already satisfied: pandas<2,>=1.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow-data-validation) (1.4.4)
# Requirement already satisfied: pyarrow<11,>=10 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow-data-validation) (10.0.1)
# Requirement already satisfied: pyfarmhash<0.4,>=0.2.2 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow-data-validation) (0.3.2)
# Requirement already satisfied: six<2,>=1.12 in /opt/conda/lib/python3.9/site-packages (from tensorflow-data-validation) (1.15.0)
# Requirement already satisfied: tensorflow<2.16,>=2.15 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow-data-validation) (2.15.1)
# Requirement already satisfied: tensorflow-metadata<1.16,>=1.15.0 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow-data-validation) (1.15.0)
# Requirement already satisfied: tfx-bsl<1.16,>=1.15.1 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow-data-validation) (1.15.1)
# Requirement already satisfied: apache-beam<3,>=2.47 in /home/jupyter/.local/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.58.1)
# Requirement already satisfied: protobuf<5,>=3.20.3 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow-data-validation) (3.20.3)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.7)
# Requirement already satisfied: orjson<4,>=3.9.7 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.10.1)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.9.4)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<2,>=1.33.1 in /home/jupyter/.local/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.66.1)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.21.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (4.21.1)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /home/jupyter/.local/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.3.0)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.6.1)
# Requirement already satisfied: packaging>=22.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (24.0)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.13.0)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.23.0)
# Requirement already satisfied: pydot<2,>=1.2.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.9.0)
# Requirement already satisfied: pytz>=2018.3 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2024.1)
# Requirement already satisfied: redis<6,>=5.0.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (5.0.3)
# Requirement already satisfied: regex>=2020.6.8 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2024.4.16)
# Requirement already satisfied: requests!=2.32.*,<3.0.0,>=2.24.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.10.0.2)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.22.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /home/jupyter/.local/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.6)
# Requirement already satisfied: js2py<1,>=0.74 in /home/jupyter/.local/lib/python3.9/site-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.74)
# Requirement already satisfied: cachetools<6,>=3.1.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (4.2.4)
# Requirement already satisfied: google-api-core<3,>=2.0.0 in /home/jupyter/.local/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.19.2)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31 in /opt/conda/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.5.31)
# Requirement already satisfied: google-auth<3,>=1.18.0 in /home/jupyter/.local/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.34.0)
# Requirement already satisfied: google-auth-httplib2<0.3.0,>=0.1.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.1.1)
# Requirement already satisfied: google-cloud-datastore<3,>=2.0.0 in /home/jupyter/.local/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.20.1)
# Requirement already satisfied: google-cloud-pubsub<3,>=2.1.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.19.2)
# Requirement already satisfied: google-cloud-pubsublite<2,>=1.2.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.10.0)
# Requirement already satisfied: google-cloud-storage<3,>=2.16.0 in /home/jupyter/.local/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.18.2)
# Requirement already satisfied: google-cloud-bigquery<4,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.18.0)
# Requirement already satisfied: google-cloud-bigquery-storage<3,>=2.6.3 in /opt/conda/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.16.2)
# Requirement already satisfied: google-cloud-core<3,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.4.1)
# Requirement already satisfied: google-cloud-bigtable<3,>=2.19.0 in /home/jupyter/.local/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.26.0)
# Requirement already satisfied: google-cloud-spanner<4,>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.44.0)
# Requirement already satisfied: google-cloud-dlp<4,>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.15.0)
# Requirement already satisfied: google-cloud-language<3,>=2.0 in /home/jupyter/.local/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.14.0)
# Requirement already satisfied: google-cloud-videointelligence<3,>=2.0 in /home/jupyter/.local/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.13.5)
# Requirement already satisfied: google-cloud-vision<4,>=2 in /opt/conda/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.6.0)
# Requirement already satisfied: google-cloud-recommendations-ai<0.11.0,>=0.1.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.7.1)
# Requirement already satisfied: google-cloud-aiplatform<2.0,>=1.26.0 in /opt/conda/lib/python3.9/site-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.41.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (3.1.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (3.3.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (69.5.1)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (1.1.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (1.12.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (0.37.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorflow<2.16,>=2.15->tensorflow-data-validation) (2.15.0)
# Requirement already satisfied: google-api-python-client<2,>=1.7.11 in /home/jupyter/.local/lib/python3.9/site-packages (from tfx-bsl<1.16,>=1.15.1->tensorflow-data-validation) (1.12.11)
# Requirement already satisfied: tensorflow-serving-api<3,>=2.13.0 in /home/jupyter/.local/lib/python3.9/site-packages (from tfx-bsl<1.16,>=1.15.1->tensorflow-data-validation) (2.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow<2.16,>=2.15->tensorflow-data-validation) (0.43.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.9/site-packages (from google-api-core<3,>=2.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.63.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl<1.16,>=1.15.1->tensorflow-data-validation) (3.0.1)
# Requirement already satisfied: oauth2client>=1.4.12 in /opt/conda/lib/python3.9/site-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (4.1.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.9/site-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.9/site-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (4.9)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /opt/conda/lib/python3.9/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.12.0)
# Requirement already satisfied: shapely<3.0.0dev in /opt/conda/lib/python3.9/site-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.0.4)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /home/jupyter/.local/lib/python3.9/site-packages (from google-cloud-bigquery<4,>=2.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/conda/lib/python3.9/site-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.12.7)
# Requirement already satisfied: grpcio-status>=1.33.2 in /opt/conda/lib/python3.9/site-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.48.1)
# Requirement already satisfied: overrides<8.0.0,>=6.0.1 in /opt/conda/lib/python3.9/site-packages (from google-cloud-pubsublite<2,>=1.2.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (7.7.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /opt/conda/lib/python3.9/site-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.5.0)
# Requirement already satisfied: deprecated>=1.2.14 in /opt/conda/lib/python3.9/site-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.2.14)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /opt/conda/lib/python3.9/site-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.15.4)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.9/site-packages (from google-cloud-storage<3,>=2.16.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (1.5.0)
# Requirement already satisfied: docopt in /opt/conda/lib/python3.9/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.6.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/lib/python3.9/site-packages (from httplib2<0.23.0,>=0.8->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.1.2)
# Requirement already satisfied: tzlocal>=1.2 in /home/jupyter/.local/lib/python3.9/site-packages (from js2py<1,>=0.74->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (5.2)
# Requirement already satisfied: pyjsparser>=2.5.1 in /home/jupyter/.local/lib/python3.9/site-packages (from js2py<1,>=0.74->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.18.0)
# Requirement already satisfied: async-timeout>=4.0.3 in /opt/conda/lib/python3.9/site-packages (from redis<6,>=5.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests!=2.32.*,<3.0.0,>=2.24.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests!=2.32.*,<3.0.0,>=2.24.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests!=2.32.*,<3.0.0,>=2.24.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests!=2.32.*,<3.0.0,>=2.24.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (2024.2.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tensorflow-data-validation) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.9/site-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tensorflow-data-validation) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/jupyter/.local/lib/python3.9/site-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tensorflow-data-validation) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tensorflow-data-validation) (3.0.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.9/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tensorflow-data-validation) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/conda/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tensorflow-data-validation) (7.1.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /opt/conda/lib/python3.9/site-packages (from oauth2client>=1.4.12->google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow-data-validation) (0.6.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tensorflow-data-validation) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tensorflow-data-validation) (3.17.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tensorflow-data-validation) (3.2.2)

# %% [markdown]
# **Restart the kernel (Kernel > Restart kernel > Restart).**
#
# **Re-run the above cell and proceed further.**
#
# **Note: Please ignore any incompatibility warnings and errors.**

# %%
import pandas as pd
import tensorflow_data_validation as tfdv
import sys
import warnings
warnings.filterwarnings('ignore')

print('Installing TensorFlow Data Validation')
# !pip install -q tensorflow_data_validation[visualization]

print('TFDV version: {}'.format(tfdv.version.__version__))
# Confirm that we're using Python 3
assert sys.version_info.major is 3, 'Oops, not running Python 3. Use Runtime > Change runtime type'
# Out:
# <>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
# 2024-09-08 19:01:52.769606: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-08 19:01:52.825878: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-08 19:01:52.825920: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-08 19:01:52.827649: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-08 19:01:52.836787: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-08 19:01:52.837361: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-08 19:01:54.396435: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Installing TensorFlow Data Validation
# TFDV version: 1.15.1

# %% [markdown]
# ###  Load the Consumer Spending Dataset
#
# We will download our dataset from Google Cloud Storage. The columns in the dataset are:
#
# * 'Graduated': Whether or not the person is a college graduate
# * 'Work Experience': The number of years in the workforce
# * 'Family Size': The size of the family unit
# * 'Spending Score': The spending score for consumer spending

# %%
# Read a comma-separated values (csv) file into DataFrame.
# TODO: Your code goes here
score_train = pd.read_csv('data/score_train.csv')
score_train.head()
# Out:
#   Graduated     Profession  Work_Experience  Family_Size Spending_Score
# 0        No     Healthcare              1.0          4.0            Low
# 1       Yes       Engineer              NaN          3.0        Average
# 2       Yes       Engineer              1.0          1.0            Low
# 3       Yes         Lawyer              0.0          2.0           High
# 4       Yes  Entertainment              NaN          6.0           High

# %%
# Read a comma-separated values (csv) file into DataFrame.
# TODO: Your code goes here
score_test = pd.read_csv('data/score_test.csv')
score_test.head()
# Out:
#   Graduated     Profession  Work_Experience  Family_Size Spending_Score
# 0        No         Doctor              0.0          5.0        Average
# 1       Yes  Entertainment              1.0          4.0        Average
# 2        No         Lawyer              0.0          5.0            Low
# 3       Yes      Executive              1.0          5.0           High
# 4       Yes         Artist              1.0          2.0        Average

# %%
score_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Graduated        3964 non-null   object
#  1   Profession       3944 non-null   object
#  2   Work_Experience  3589 non-null   float64
#  3   Family_Size      3831 non-null   float64
#  4   Spending_Score   4000 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 156.4+ KB

# %% [markdown]
# #### Review the methods present in TFDV

# %%
# check methods present in tfdv
# TODO: Your code goes here
dir(tfdv)
# Out:
# ['CombinerStatsGenerator',
#  'CrossFeatureView',
#  'DatasetListView',
#  'DatasetView',
#  'DetectFeatureSkew',
#  'FeaturePath',
#  'FeatureView',
#  'GenerateStatistics',
#  'MergeDatasetFeatureStatisticsList',
#  'StatsOptions',
#  'TransformStatsGenerator',
#  'WriteStatisticsToBinaryFile',
#  'WriteStatisticsToRecordsAndBinaryFile',
#  'WriteStatisticsToTFRecord',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'anomalies',
#  'api',
#  'arrow',
#  'coders',
#  'compare_slices',
#  'constants',
#  'default_sharded_output_suffix',
#  'default_sharded_output_supported',
#  'display_anomalies',
#  'display_schema',
#  'experimental_get_feature_value_slicer',
#  'generate_dummy_schema_with_paths',
#  'generate_statistics_from_csv',
#  'generate_statistics_from_dataframe',
#  'generate_statistics_from_tfrecord',
#  'get_confusion_count_dataframes',
#  'get_domain',
#  'get_feature',
#  'get_feature_stats',
#  'get_match_stats_dataframe',
#  'get_skew_result_dataframe',
#  'get_slice_stats',
#  'get_statistics_html',
#  'infer_schema',
#  'load_anomalies_text',
#  'load_schema_text',
#  'load_sharded_statistics',
#  'load_statistics',
#  'load_stats_binary',
#  'load_stats_text',
#  'pywrap',
#  'set_domain',
#  'skew',
#  'statistics',
#  'types',
#  'update_schema',
#  'utils',
#  'validate_corresponding_slices',
#  'validate_examples_in_csv',
#  'validate_examples_in_tfrecord',
#  'validate_statistics',
#  'version',
#  'visualize_statistics',
#  'write_anomalies_text',
#  'write_schema_text',
#  'write_stats_text']

# %% [markdown]
# ### Describing data with TFDV
# The usual workflow when using TFDV during training is as follows:
#
#
# 1.   Generate statistics for the data
# 2.   Use those statistics to generate a schema for each feature
# 3.   Visualize the schema and statistics and manually inspect them
# 4.   Update the schema if needed

# %% [markdown]
# ### Compute and visualize statistics
#
# First we'll use [`tfdv.generate_statistics_from_csv`](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/generate_statistics_from_csv) to compute statistics for our training data. (ignore the snappy warnings)
#
# TFDV can compute descriptive [statistics](https://github.com/tensorflow/metadata/blob/v0.6.0/tensorflow_metadata/proto/v0/statistics.proto) that provide a quick overview of the data in terms of the features that are present and the shapes of their value distributions.
#
# Internally, TFDV uses [Apache Beam](https://beam.apache.org/)'s data-parallel processing framework to scale the computation of statistics over large datasets. For applications that wish to integrate deeper with TFDV (e.g., attach statistics generation at the end of a data-generation pipeline), the API also exposes a Beam PTransform for statistics generation.
#
# **NOTE:  Compute statistics**
# * [tfdv.generate_statistics_from_csv](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/generate_statistics_from_csv)
# * [tfdv.generate_statistics_from_dataframe](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/generate_statistics_from_dataframe)
# * [tfdv.generate_statistics_from_tfrecord](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/generate_statistics_from_tfrecord)

# %% [markdown]
# #### Generate Statistics from a Pandas DataFrame

# %%
# Compute data statistics for the input pandas DataFrame.
# TODO: Your code goes here
stats = tfdv.generate_statistics_from_dataframe(score_train)
stats
# Out:
# datasets {
#   num_examples: 4000
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 3964
#         num_missing: 36
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 396.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 396.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 396.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 396.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 396.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 396.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 396.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 396.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 396.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 396.4
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 3964
#       }
#       unique: 2
#       top_values {
#         value: "Yes"
#         frequency: 2433.0
#       }
#       top_values {
#         value: "No"
#         frequency: 1531.0
#       }
#       avg_length: 2.613774061203003
#       rank_histogram {
#         buckets {
#           label: "Yes"
#           sample_count: 2433.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "No"
#           sample_count: 1531.0
#         }
#       }
#     }
#     path {
#       step: "Graduated"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 3944
#         num_missing: 56
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 394.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 394.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 394.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 394.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 394.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 394.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 394.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 394.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 394.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 394.4
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 3944
#       }
#       unique: 9
#       top_values {
#         value: "Artist"
#         frequency: 1218.0
#       }
#       top_values {
#         value: "Healthcare"
#         frequency: 666.0
#       }
#       top_values {
#         value: "Entertainment"
#         frequency: 476.0
#       }
#       top_values {
#         value: "Engineer"
#         frequency: 351.0
#       }
#       top_values {
#         value: "Doctor"
#         frequency: 344.0
#       }
#       top_values {
#         value: "Lawyer"
#         frequency: 312.0
#       }
#       top_values {
#         value: "Executive"
#         frequency: 300.0
#       }
#       top_values {
#         value: "Marketing"
#         frequency: 155.0
#       }
#       top_values {
#         value: "Homemaker"
#         frequency: 122.0
#       }
#       avg_length: 8.137170791625977
#       rank_histogram {
#         buckets {
#           label: "Artist"
#           sample_count: 1218.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "Healthcare"
#           sample_count: 666.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "Entertainment"
#           sample_count: 476.0
#         }
#         buckets {
#           low_rank: 3
#           high_rank: 3
#           label: "Engineer"
#           sample_count: 351.0
#         }
#         buckets {
#           low_rank: 4
#           high_rank: 4
#           label: "Doctor"
#           sample_count: 344.0
#         }
#         buckets {
#           low_rank: 5
#           high_rank: 5
#           label: "Lawyer"
#           sample_count: 312.0
#         }
#         buckets {
#           low_rank: 6
#           high_rank: 6
#           label: "Executive"
#           sample_count: 300.0
#         }
#         buckets {
#           low_rank: 7
#           high_rank: 7
#           label: "Marketing"
#           sample_count: 155.0
#         }
#         buckets {
#           low_rank: 8
#           high_rank: 8
#           label: "Homemaker"
#           sample_count: 122.0
#         }
#       }
#     }
#     path {
#       step: "Profession"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 3589
#         num_missing: 411
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 358.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 358.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 358.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 358.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 358.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 358.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 358.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 358.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 358.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 358.9
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 3589
#       }
#       mean: 2.6517135692393423
#       std_dev: 3.4199292161219956
#       num_zeros: 1132
#       median: 1.0
#       max: 14.0
#       histograms {
#         buckets {
#           high_value: 1.4
#           sample_count: 2310.457142857154
#         }
#         buckets {
#           low_value: 1.4
#           high_value: 2.8
#           sample_count: 154.34285714285707
#         }
#         buckets {
#           low_value: 2.8
#           high_value: 4.199999999999999
#           sample_count: 247.9076923076922
#         }
#         buckets {
#           low_value: 4.199999999999999
#           high_value: 5.6
#           sample_count: 93.45230769230767
#         }
#         buckets {
#           low_value: 5.6
#           high_value: 7.0
#           sample_count: 212.83999999999983
#         }
#         buckets {
#           low_value: 7.0
#           high_value: 8.399999999999999
#           sample_count: 227.4440677966103
#         }
#         buckets {
#           low_value: 8.399999999999999
#           high_value: 9.799999999999999
#           sample_count: 214.52736077481848
#         }
#         buckets {
#           low_value: 9.799999999999999
#           high_value: 11.2
#           sample_count: 51.703571428571436
#         }
#         buckets {
#           low_value: 11.2
#           high_value: 12.6
#           sample_count: 28.845000000000002
#         }
#         buckets {
#           low_value: 12.6
#           high_value: 14.0
#           sample_count: 47.48
#         }
#       }
#       histograms {
#         buckets {
#           sample_count: 377.3333333333333
#         }
#         buckets {
#           sample_count: 377.3333333333333
#         }
#         buckets {
#           sample_count: 377.3333333333333
#         }
#         buckets {
#           high_value: 1.0
#           sample_count: 392.3333333333333
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 392.3333333333333
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 392.3333333333333
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 3.0
#           sample_count: 272.0
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 6.0
#           sample_count: 331.0
#         }
#         buckets {
#           low_value: 6.0
#           high_value: 8.0
#           sample_count: 333.0
#         }
#         buckets {
#           low_value: 8.0
#           high_value: 14.0
#           sample_count: 344.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "Work_Experience"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 3831
#         num_missing: 169
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 383.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 383.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 383.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 383.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 383.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 383.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 383.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 383.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 383.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 383.1
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 3831
#       }
#       mean: 2.8449490994518403
#       std_dev: 1.514559960152969
#       min: 1.0
#       median: 3.0
#       max: 9.0
#       histograms {
#         buckets {
#           low_value: 1.0
#           high_value: 1.8
#           sample_count: 718.0601941747606
#         }
#         buckets {
#           low_value: 1.8
#           high_value: 2.6
#           sample_count: 1181.2449078660557
#         }
#         buckets {
#           low_value: 2.6
#           high_value: 3.4000000000000004
#           sample_count: 752.227858853036
#         }
#         buckets {
#           low_value: 3.4000000000000004
#           high_value: 4.2
#           sample_count: 685.232039106145
#         }
#         buckets {
#           low_value: 4.2
#           high_value: 5.0
#           sample_count: 305.23499999999956
#         }
#         buckets {
#           low_value: 5.0
#           high_value: 5.800000000000001
#           sample_count: 3.0720000000000027
#         }
#         buckets {
#           low_value: 5.800000000000001
#           high_value: 6.6000000000000005
#           sample_count: 95.11371428571432
#         }
#         buckets {
#           low_value: 6.6000000000000005
#           high_value: 7.4
#           sample_count: 50.414285714285725
#         }
#         buckets {
#           low_value: 7.4
#           high_value: 8.2
#           sample_count: 23.119999999999997
#         }
#         buckets {
#           low_value: 8.2
#           high_value: 9.0
#           sample_count: 17.28
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 715.0
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 2.0
#           sample_count: 394.0
#         }
#         buckets {
#           low_value: 2.0
#           high_value: 2.0
#           sample_count: 394.0
#         }
#         buckets {
#           low_value: 2.0
#           high_value: 2.0
#           sample_count: 394.0
#         }
#         buckets {
#           low_value: 2.0
#           high_value: 3.0
#           sample_count: 376.5
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 3.0
#           sample_count: 376.5
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 4.0
#           sample_count: 343.0
#         }
#         buckets {
#           low_value: 4.0
#           high_value: 4.0
#           sample_count: 343.0
#         }
#         buckets {
#           low_value: 4.0
#           high_value: 5.0
#           sample_count: 306.0
#         }
#         buckets {
#           low_value: 5.0
#           high_value: 9.0
#           sample_count: 189.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "Family_Size"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 4000
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 400.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 400.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 400.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 400.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 400.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 400.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 400.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 400.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 400.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 400.0
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 4000
#       }
#       unique: 3
#       top_values {
#         value: "Low"
#         frequency: 2448.0
#       }
#       top_values {
#         value: "Average"
#         frequency: 969.0
#       }
#       top_values {
#         value: "High"
#         frequency: 583.0
#       }
#       avg_length: 4.114749908447266
#       rank_histogram {
#         buckets {
#           label: "Low"
#           sample_count: 2448.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "Average"
#           sample_count: 969.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "High"
#           sample_count: 583.0
#         }
#       }
#     }
#     path {
#       step: "Spending_Score"
#     }
#   }
# }

# %% [markdown]
# Now let's use [`tfdv.visualize_statistics`](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/visualize_statistics), which uses [Facets](https://pair-code.github.io/facets/) to create a succinct visualization of our training data:
#
# * Notice that numeric features and categorical features are visualized separately, and that charts are displayed showing the distributions for each feature.
# * Notice that features with missing or zero values display a percentage in red as a visual indicator that there may be issues with examples in those features.  The percentage is the percentage of examples that have missing or zero values for that feature.
# * Notice that there are no examples with values for `pickup_census_tract`.  This is an opportunity for dimensionality reduction!
# * Try clicking "expand" above the charts to change the display
# * Try hovering over bars in the charts to display bucket ranges and counts
# * Try switching between the log and linear scales, and notice how the log scale reveals much more detail about the `payment_type` categorical feature
# * Try selecting "quantiles" from the "Chart to show" menu, and hover over the markers to show the quantile percentages

# %%
# Visualize the input statistics using Facets.
# TODO: Your code goes here
tfdv.visualize_statistics(stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# #### TFDV generates different types of statistics based on the type of features.
#
# **For numerical features, TFDV computes for every feature:**
# * Count of records
# * Number of missing (i.e. null values)
# * Histogram of values
# * Mean and standard deviation
# * Minimum and maximum values
# * Percentage of zero values
#
# **For categorical features, TFDV provides:**
# * Count of values
# * Percentage of missing values
# * Number of unique values
# * Average string length
# * Count for each label and its rank

# %% [markdown]
# ### Let's compare the score_train and the score_test datasets

# %%
train_stats = tfdv.generate_statistics_from_dataframe(dataframe=score_train)
test_stats = tfdv.generate_statistics_from_dataframe(dataframe=score_test)

tfdv.visualize_statistics(
  lhs_statistics=train_stats, lhs_name='TRAIN_DATASET',
  rhs_statistics=test_stats, rhs_name='NEW_DATASET')
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ### Infer a schema
#
# Now let's use [`tfdv.infer_schema`](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/infer_schema) to create a schema for our data.  A schema defines constraints for the data that are relevant for ML. Example constraints include the data type of each feature, whether it's numerical or categorical, or the frequency of its presence in the data.  For categorical features the schema also defines the domain - the list of acceptable values.  Since writing a schema can be a tedious task, especially for datasets with lots of features, TFDV provides a method to generate an initial version of the schema based on the descriptive statistics.
#
# Getting the schema right is important because the rest of our production pipeline will be relying on the schema that TFDV generates to be correct.

# %% [markdown]
# #### Generating Schema
# Once statistics are generated, the next step is to generate a schema for our dataset. This schema will map each feature in the dataset to a type (float, bytes, etc.). Also define feature boundaries (min, max, distribution of values and missings, etc.).
#
# Link to infer schema
# https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/infer_schema
#
# With TFDV, we generate schema from statistics using

# %%
# Infers schema from the input statistics.
# TODO: Your code goes here
schema = tfdv.infer_schema(stats)
print(schema)
# Out:
# feature {
#   name: "Graduated"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   domain: "Graduated"
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "Profession"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   domain: "Profession"
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "Work_Experience"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "Family_Size"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "Spending_Score"
#   type: BYTES
#   domain: "Spending_Score"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# string_domain {
#   name: "Graduated"
#   value: "No"
#   value: "Yes"
# }
# string_domain {
#   name: "Profession"
#   value: "Artist"
#   value: "Doctor"
#   value: "Engineer"
#   value: "Entertainment"
#   value: "Executive"
#   value: "Healthcare"
#   value: "Homemaker"
#   value: "Lawyer"
#   value: "Marketing"
# }
# string_domain {
#   name: "Spending_Score"
#   value: "Average"
#   value: "High"
#   value: "Low"
# }

# %% [markdown]
# The schema also provides documentation for the data, and so is useful when different developers work on the same data.  Let's use [`tfdv.display_schema`](https://www.tensorflow.org/tfx/data_validation/api_docs/python/tfdv/display_schema) to display the inferred schema so that we can review it.

# %%
tfdv.display_schema(schema=schema)
# Out:
#                      Type  Presence Valency            Domain
# Feature name
# 'Graduated'        STRING  optional  single       'Graduated'
# 'Profession'       STRING  optional  single      'Profession'
# 'Work_Experience'   FLOAT  optional  single                 -
# 'Family_Size'       FLOAT  optional  single                 -
# 'Spending_Score'   STRING  required          'Spending_Score'
#                                                                                                                           Values
# Domain
# 'Graduated'                                                                                                          'No', 'Yes'
# 'Profession'      'Artist', 'Doctor', 'Engineer', 'Entertainment', 'Executive', 'Healthcare', 'Homemaker', 'Lawyer', 'Marketing'
# 'Spending_Score'                                                                                        'Average', 'High', 'Low'

# %% [markdown]
# #### TFDV provides a API to print a summary of each feature schema using
#
# In this visualization, the columns stand for:
#
# **Type** indicates the feature datatype.
#
# **Presence** indicates whether the feature must be present in 100% of examples (required) or not (optional).
#
# **Valency** indicates the number of values required per training example.
#
# **Domain and Values** indicates The feature domain and its values
#
# In the case of categorical features, single indicates that each training example must have exactly one category for the feature.

# %% [markdown]
# ### Updating the Schema
# As stated above, **Presence** indicates whether the feature must be present in 100% of examples (required) or not (optional).  Currently, all of our features except for our target label are shown as "optional". We need to make our features all required except for "Work Experience".  We will need to update the schema.

# %% [markdown]
# TFDV lets you update the schema according to your domain knowledge of the data if you are not satisfied by the auto-generated schema.  We will update three use cases:  Making a feature required, adding a value to a feature, and change a feature from a float to an integer.

# %% [markdown]
# #### Change optional features to required.

# %%
# Update Family_Size from FLOAT to Int
Graduated_feature = tfdv.get_feature(schema, 'Graduated')
Graduated_feature.presence.min_fraction = 1.0
Profession_feature = tfdv.get_feature(schema, 'Profession')
Profession_feature.presence.min_fraction = 1.0
Family_Size_feature = tfdv.get_feature(schema, 'Family_Size')
Family_Size_feature.presence.min_fraction = 1.0

# %%
tfdv.display_schema(schema)
# Out:
#                      Type  Presence Valency            Domain
# Feature name
# 'Graduated'        STRING  required  single       'Graduated'
# 'Profession'       STRING  required  single      'Profession'
# 'Work_Experience'   FLOAT  optional  single                 -
# 'Family_Size'       FLOAT  required  single                 -
# 'Spending_Score'   STRING  required          'Spending_Score'
#                                                                                                                           Values
# Domain
# 'Graduated'                                                                                                          'No', 'Yes'
# 'Profession'      'Artist', 'Doctor', 'Engineer', 'Entertainment', 'Executive', 'Healthcare', 'Homemaker', 'Lawyer', 'Marketing'
# 'Spending_Score'                                                                                        'Average', 'High', 'Low'

# %% [markdown]
# #### Update a feature with a new value

# %% [markdown]
# Let's add "self-employed" to the Profession feature

# %%
Profession_domain = tfdv.get_domain(schema, 'Profession')
Profession_domain.value.insert(0, 'Self-Employed')
Profession_domain.value
# [0 indicates I want 'Self-Employed to come first', if the number were 3, 
# it would be placed after the third value. ]
# Out:
# ['Self-Employed', 'Artist', 'Doctor', 'Engineer', 'Entertainment', 'Executive', 'Healthcare', 'Homemaker', 'Lawyer', 'Marketing']

# %% [markdown]
# #### Let's remove "Homemaker" from "Profession"

# %%
Profession_domain = tfdv.get_domain(schema, 'Profession')
Profession_domain.value.remove('Homemaker')

# %%
Profession_domain.value
# Out:
# ['Self-Employed', 'Artist', 'Doctor', 'Engineer', 'Entertainment', 'Executive', 'Healthcare', 'Lawyer', 'Marketing']

# %% [markdown]
# #### Change a feature from a float to an integer

# %%
# Update Family_Size to Int
size = tfdv.get_feature(schema, 'Family_Size')

# %%
size.type=2
tfdv.display_schema(schema)
# Out:
#                      Type  Presence Valency            Domain
# Feature name
# 'Graduated'        STRING  required  single       'Graduated'
# 'Profession'       STRING  required  single      'Profession'
# 'Work_Experience'   FLOAT  optional  single                 -
# 'Family_Size'         INT  required  single                 -
# 'Spending_Score'   STRING  required          'Spending_Score'
#                                                                                                                               Values
# Domain
# 'Graduated'                                                                                                              'No', 'Yes'
# 'Profession'      'Self-Employed', 'Artist', 'Doctor', 'Engineer', 'Entertainment', 'Executive', 'Healthcare', 'Lawyer', 'Marketing'
# 'Spending_Score'                                                                                            'Average', 'High', 'Low'

# %% [markdown]
# In the next lab, you compare two datasets and check for anomalies.

# %% [markdown]
# ## When to use TFDV
#
# It's easy to think of TFDV as only applying to the start of your training pipeline, as we did here, but in fact it has many uses. Here are a few more:
#
# * Validating new data for inference to make sure that we haven't suddenly started receiving bad features
# * Validating new data for inference to make sure that our model has trained on that part of the decision surface
# * Validating our data after we've transformed it and done feature engineering (probably using [TensorFlow Transform](https://www.tensorflow.org/tfx/guide/transform)) to make sure we haven't done something wrong

# %% [markdown]
# https://github.com/GoogleCloudPlatform/mlops-on-gcp/blob/master/examples/tfdv-structured-data/tfdv-covertype.ipynb
