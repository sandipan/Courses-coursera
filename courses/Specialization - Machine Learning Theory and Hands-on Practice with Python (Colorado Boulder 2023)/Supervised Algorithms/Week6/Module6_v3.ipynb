# %% [markdown]
# ### Grading
# The final score that you will receive for your programming assignment is generated in relation to the total points set in your programming assignment item—not the total point value in the nbgrader notebook.<br>
# When calculating the final score shown to learners, the programming assignment takes the percentage of earned points vs. the total points provided by nbgrader and returns a score matching the equivalent percentage of the point value for the programming assignment.<br>
# **DO NOT CHANGE VARIABLE OR METHOD SIGNATURES** The autograder will not work properly if your change the variable or method signatures.

# %% [markdown]
# ### WARNING
# Please refrain from using **print statements/anything that dumps large outputs(>500 lines) to STDOUT** to avoid running to into **memory issues**.
# Doing so requires your entire lab to be reset which may also result in loss of progress and you will be required to reach out to Coursera for assistance with this.
# This process usually takes time causing delays to your submission.

# %% [markdown]
# ### Validate Button
# Please note that this assignment uses nbgrader to facilitate grading. You will see a **validate button** at the top of your Jupyter notebook. If you hit this button, it will run tests cases for the lab that aren't hidden. It is good to use the validate button before submitting the lab. Do know that the labs in the course contain hidden test cases. The validate button will not let you know whether these test cases pass. After submitting your lab, you can see more information about these hidden test cases in the Grader Output. <br>
# ***Cells with longer execution times will cause the validate button to time out and freeze. Please know that if you run into Validate time-outs, it will not affect the final submission grading.*** <br>

# %% [markdown]
# # Homework 6: Support Vector Machines
# ***
#
# In this assignment we'll explore the details of the Soft-Margin SVM and look at how the choice of tuning parameters  affects the learned models.  We'll also look at kernel SVMs for non-linearly separable and methods for choosing and visualizing good hyperparameters.
#
# **Note**: Below are some helper functions which are used throughout this notebook.  Execute these before continuing. Do not modify.

# %%
import numpy as np
from sklearn.datasets import make_blobs
from matplotlib.colors import Normalize
import matplotlib.pyplot as plt
# %matplotlib inline

def linear_plot(X, y, w=None, b=None):
    
    mycolors = {"blue": "steelblue", "red": "#a76c6e", "green": "#6a9373"}
    colors = [mycolors["red"] if yi==1 else mycolors["blue"] for yi in y]
    
    # Plot data 
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,8))
    ax.scatter(X[:,0], X[:,1], color=colors, s=150, alpha=0.95, zorder=2)
    
    # Plot boundaries 
    lower_left = np.min([np.min(X[:,0]), np.min(X[:,1])])
    upper_right = np.max([np.max(X[:,0]), np.max(X[:,1])])
    gap = .1*(upper_right-lower_left)
    xplot = np.linspace(lower_left-gap, upper_right+gap, 20)
    if w is not None and b is not None: 
        ax.plot(xplot, (-b - w[0]*xplot)/w[1], color="gray", lw=2, zorder=1)
        ax.plot(xplot, ( 1 -b - w[0]*xplot)/w[1], color="gray", lw=2, ls="--", zorder=1)
        ax.plot(xplot, (-1 -b - w[0]*xplot)/w[1], color="gray", lw=2, ls="--", zorder=1)
        
    
    ax.set_xlim([lower_left-gap, upper_right+gap])
    ax.set_ylim([lower_left-gap, upper_right+gap])
    
    ax.grid(alpha=0.25)
    
def part2data():
    
    np.random.seed(1239)
    
    X = np.zeros((22,2))
    X[0:10,0]  = 1.5*np.random.rand(10) 
    X[0:10,1]  = 1.5*np.random.rand(10)
    X[10:20,0] = 1.5*np.random.rand(10) +  1.75
    X[10:20,1] = 1.5*np.random.rand(10) +  1
    X[20,0] = 1.5
    X[20,1] = 2.25
    X[21,0] = 1.6
    X[21,1] = 0.25
    
    y = np.ones(22)
    y[10:20] = -1 
    y[20] = 1
    y[21] = -1
    
    return X, y

def part3data(N=100, seed=1235):
    
    np.random.seed(seed)
    
    X = np.random.uniform(-1,1,(N,2))
    y = np.array([1 if y-x > 0 else -1 for (x,y) in zip(X[:,0]**2 * np.sin(2*np.pi*X[:,0]), X[:,1])])
    X = X + np.random.normal(0,.1,(N,2))
    
    return X, y

def nonlinear_plot(X, y, clf=None): 
    
    mycolors = {"blue": "steelblue", "red": "#a76c6e", "green": "#6a9373"}
    
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,10))
    
    colors = [mycolors["red"] if yi==1 else mycolors["blue"] for yi in y]
    ax.scatter(X[:,0],X[:,1], marker='o', color=colors, s=100, alpha=0.5)
    
    ax.arrow(-1.25,0,2.5,0, head_length=0.05, head_width=0.05, fc="gray", ec="gray", lw=2, alpha=0.25)
    ax.arrow(0,-1.25,0,2.5, head_length=0.05, head_width=0.05, fc="gray", ec="gray", lw=2, alpha=0.25)
    z = np.linspace(0.25,3.5,10)
    
    ax.set_xlim([-1.50,1.50])
    ax.set_ylim([-1.50,1.50])
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    plt.xticks([], fontsize=16)
    plt.yticks([], fontsize=16)
    

    if clf: 
        
        clf.fit(X,y)

        x_min = X[:, 0].min()+.00
        x_max = X[:, 0].max()-.00
        y_min = X[:, 1].min()+.00
        y_max = X[:, 1].max()-.00

        colors = [mycolors["red"] if yi==1 else mycolors["blue"] for yi in y]

        XX, YY = np.mgrid[x_min:x_max:200j, y_min:y_max:200j]
        Z = clf.decision_function(np.c_[XX.ravel(), YY.ravel()])

        # Put the result into a color plot
        Z = Z.reshape(XX.shape)
        plt.contour(XX, YY, Z, colors=[mycolors["blue"], "gray", mycolors["red"]], linestyles=['--', '-', '--'],
                    levels=[-1.0, 0, 1.0], linewidths=[2,2,2], alpha=0.9)
    

class MidpointNormalize(Normalize):

    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y))
    
def plotSearchGrid(grid):
    
    scores = [x for x in grid.cv_results_["mean_test_score"]]
    scores = np.array(scores).reshape(len(grid.param_grid["C"]), len(grid.param_grid["gamma"]))

    plt.figure(figsize=(10, 8))
    plt.subplots_adjust(left=.2, right=0.95, bottom=0.15, top=0.95)
    plt.imshow(scores, interpolation='nearest', cmap=plt.cm.hot,
               norm=MidpointNormalize(vmin=0.2, midpoint=0.92))
    plt.xlabel('gamma')
    plt.ylabel('C')
    plt.colorbar()
    plt.xticks(np.arange(len(grid.param_grid["gamma"])), grid.param_grid["gamma"], rotation=45)
    plt.yticks(np.arange(len(grid.param_grid["C"])), grid.param_grid["C"])
    plt.title('Validation accuracy')
    plt.show()

from IPython.core.display import HTML
HTML("""
<style>
.MathJax nobr>span.math>span{border-left-width:0 !important};
</style>
""")
# Out:
# <style>
# .MathJax nobr>span.math>span{border-left-width:0 !important};
# </style>

# %% [markdown]
# ### Part 1: SVM [20 pts, Peer Review]

# %%
import numpy as np

# Data and Labels 
X = np.array([[1,8],[7,2],[6,-1],[-5,0], [-5,1], [-5,2],[6,3],[6,1],[5,2]])
y = np.array([1,-1,-1,1,-1,1,1,-1,-1])

# Support vector parameters 
w, b = np.array([-1/4, 1/4]), -1/4

# Plot the data and support vector boundaries 
linear_plot(X, y, w=w, b=b)

# %% [markdown]
# **Part A [5 pts]**: What is the margin of this particular SVM?

# %%
margin = 1 / (np.linalg.norm(w)) # update margin to be a correct number

# your code here

def test_svm_plot():
    import numpy as np
    import matplotlib.pyplot as plt
    from sklearn import svm

    # we create 40 separable points
    np.random.seed(0)
    X = np.r_[np.random.randn(20, 2) - [2, 2], np.random.randn(20, 2) + [2, 2]]
    Y = [0] * 20 + [1] * 20

    # fit the model
    clf = svm.SVC(kernel='linear')
    clf.fit(X, Y)

    # get the separating hyperplane
    w = clf.coef_[0]
    a = -w[0] / w[1]
    xx = np.linspace(-5, 5)
    yy = a * xx - (clf.intercept_[0]) / w[1]

    # plot the parallels to the separating hyperplane that pass through the
    # support vectors
    b = clf.support_vectors_[0]
    yy_down = a * xx + (b[1] - a * b[0])
    b = clf.support_vectors_[-1]
    yy_up = a * xx + (b[1] - a * b[0])

    # plot the line, the points, and the nearest vectors to the plane
    plt.plot(xx, yy, 'k-')
    plt.plot(xx, yy_down, 'k--')
    plt.plot(xx, yy_up, 'k--')

    plt.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1],
                s=80, facecolors='none')
    plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired)

    plt.axis('tight')
    plt.show()

def plot_SVC(X, y, C=5):
    from sklearn import svm
    clf = svm.SVC(kernel="linear", C=C)
    #clf = svm.LinearSVC(C=1e8)
    clf.fit(X, y)
    print(clf.coef_, 
      clf.coef0, 
      clf.dual_coef_,
      clf.n_support_, 
      clf.support_vectors_
     )
    w = clf.coef_[0]
    b = clf.coef0 
    linear_plot(X, y, w=w, b=b)
    
    '''
    # get the separating hyperplane
    w = clf.coef_[0]
    print('w=:', w)
    a = -w[0] / w[1]
    xx = np.linspace(-6, 8)
    yy = a * xx - (clf.intercept_[0]) / w[1]

    
    # plot the parallels to the separating hyperplane that pass through the
    # support vectors
    b = clf.support_vectors_[0]
    yy_down = a * xx + (b[1] - a * b[0])
    b = clf.support_vectors_[-1]
    yy_up = a * xx + (b[1] - a * b[0])

    # plot the line, the points, and the nearest vectors to the plane
    plt.plot(xx, yy, 'k-')
    plt.plot(xx, yy_down, 'k--')
    plt.plot(xx, yy_up, 'k--')

    plt.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1],
                s=80, facecolors='none')
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)
 
    # plot the parallels to the separating hyperplane that pass through the
    # support vectors (margin away from hyperplane in direction
    # perpendicular to hyperplane). This is sqrt(1+a^2) away vertically in
    # 2-d.
    margin = 1 / np.sqrt(np.sum(clf.coef_**2))
    yy_down = yy - np.sqrt(1 + a**2) * margin
    yy_up = yy + np.sqrt(1 + a**2) * margin

    # plot the line, the points, and the nearest vectors to the plane
    plt.figure(figsize=(10, 10))
    plt.clf()
    plt.plot(xx, yy, "k-")
    plt.plot(xx, yy_down, "k--")
    plt.plot(xx, yy_up, "k--")

    plt.scatter(
        clf.support_vectors_[:, 0],
        clf.support_vectors_[:, 1],
        s=80,
        facecolors="red",
        zorder=10,
        edgecolors="red",
        cmap=plt.get_cmap("RdBu"),
    )
    plt.scatter(
        X[:, 0], X[:, 1], c=y, zorder=10, cmap=plt.get_cmap("RdBu"), edgecolors="k"
    )

    plt.axis("tight")
    x_min = -6 #-4.8
    x_max = 8 #4.2
    y_min = -6
    y_max = 8 #6

    YY, XX = np.meshgrid(yy, xx)
    xy = np.vstack([XX.ravel(), YY.ravel()]).T
    Z = clf.decision_function(xy).reshape(XX.shape)

    # Put the result into a contour plot
    plt.contourf(XX, YY, Z, cmap=plt.get_cmap("RdBu"), alpha=0.5, linestyles=["-"])
    
    
    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)
    '''
    
    plt.xticks(())
    plt.yticks(())

    plt.show()

    return 1 / np.sqrt(np.sum(clf.coef_**2))

#test_svm_plot()

#plot_SVC(X, y,C=1e0)
#1 / (np.linalg.norm(w))

# %%
# tests that margin was updated correctly

# %% [markdown]
# **Part B [5 pts, Peer Review]**: Which training examples are the support vectors? Assign the coordinate in the list. e.g. support_vectors = [(1,0),(0,0)]

# %%
# uncomment and update support_vectors  
support_vectors = [(-5,0), (-5,1), (5,2), (6,3)];
# your code here

def calculate_support_vectors(X, y, w, b, threshold=1e-6):     
    support_vectors = []     
    for i in range(len(X)):         
        condition = y[i] * (np.dot(w, X[i]) + b)      
        #print(X[i], condition)
        if condition <= 1:            
            support_vectors.append(tuple(X[i]))     
    return support_vectors  

#support_vectors = [(-5,0), (-5,1), (5,2), (6,3)];
#support_vectors = [(7,  2), (-5,  1), (5,  2), (1, 8), (-5, 0), (-5, 2), (6, 3)];
#for i in range(X.shape[0]):
#    print(X[i], y[i]*(w@X[i]+b) <= 1)
calculate_support_vectors(X, y, w, b)
#support_vectors
# Out:
# [(-5, 0), (-5, 1), (6, 3), (5, 2)]

# %%
# tests support_vectors

# %% [markdown]
# Answer the following question in this week's **Peer Review assignment**:<br>
# Explain your answer for which training examples are support vectors. For the support vectors that you have identified, which are the in-bound support vectors and which are the out-bound support vectors?

# %%
# instructor testing cell 
# your code here

# %% [markdown]
# **Part C [5 pts, Peer Review]**: Which training examples have nonzero slack? List their coordinates.

# %%
# list of coordinates with nonzero slack 
nonzero_slack = [(-5,  1), (6,  3)];
# your code here
def predict(X, w, b):
    return np.sign(X@w+b);

def compute_slacks(X, y, w, b):
    return np.maximum(0, 1 - y*(X@w + b))
    #return 1 - np.sign(y*(X@w + b))

#nonzero_slack
compute_slacks(X, y, w, b)
#predict(X, w, b) == y
X[[4,6]]
# Out:
# array([[-5,  1],
#        [ 6,  3]])

# %%
# tests nonzero_slack list

# %% [markdown]
# Answer the following question in this week's **Peer Review assignment**: <br>
# How did you know which training examples had nonzero slack?

# %%
# instructor testing cell
# your code here

# %% [markdown]
# **Part D [5 pts, Peer Review]**: Compute the slack $\xi_i$ associated with the misclassified points.
#
# Slack Formula:
# #### ξ<sub>i</sub> = 1 −  y<sub>i</sub> ( w<sup>T</sup> x<sub>i</sub>  + b )

# %%
# your code here
# compute the slack associated with the misclassified points
# return a list slacks with the slack computations
slacks = compute_slacks(X, y, w, b)
# slacks = [slack1, slack2]
slacks = slacks[slacks > 1]
# slack1 = slacks[0]
# slack2 = slacks[1]
print(slacks)
# Out:
# [2.25 2.  ]

# %%
# tests slacks

# %% [markdown]
# Answer the following question in your **Peer Review assignment for the week**: <br>
# Do these slack values agree with the plot of the data and the support vector boundaries?

# %% [markdown]
# ### Part 2: The Margin vs Slack
# ***
#
# In this problem we'll figure out how to fit linear SVM models to data using sklearn.  Consider the data shown below.

# %%
X, y = part2data()
linear_plot(X, y)

# %% [markdown]
# **Part A [5 pts]**: Let's fit a linear Soft-Margin SVM to the data above. For SVMs with a linear kernel we'll use the [`LinearSVM`](http://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html) method from sklearn's `svm` module.  Go now and look at the documentation.
#
# Recall that the primal objective function for the linear kernel SVM is as follows
#
#
# $$
# \min_{{\bf w}, b, {\bf \xi}} \frac{1}{2}\|{\bf w}\|^2 + C \sum_{i=1}^m \xi_i^p.
# $$
# **Note that the C parameter definition in sklearn is different from the textbook.**
#
# The two optional parameters in `LinearSVM` that we'll be most concerned with are `C`, the hyperparameter weighting the slackness contribution to the primal objective function, and `loss`, which determines the exponent on the slack variables in the sum. When $p=1$ from above equation, the loss is hinge loss, whereas is $p=2$, it's $L2$ form, the loss is called squared-hinge.
#
# Write some code below to train a linear SVM with $C=1$ and $p=1$, get the computed weight vector and bias, and the plot the resulting model.

# %%
from sklearn.svm import LinearSVC

# TODO: Build a LinearSVC model called lsvm. Train the model and get the parameters, pay attention to the loss parameter
lsvm = None
# your code here
lsvm = LinearSVC(C=1, loss='hinge')
lsvm.fit(X, y)

# use this code to plot the resulting model
w = lsvm.coef_[0]
b = lsvm.intercept_
print(w,b)
linear_plot(X, y, w=w, b=b)
# Out:
# [-1.41897528  0.30584252] [1.76759606]

# %%
# tests w and b

# %% [markdown]
# **Part B**: Experiment with different values of `C`.  Answer the following question in your Peer Review for the week: How does the choice of `C` affect the nature of the decision boundary and the associated margin?

# %%
from sklearn.svm import LinearSVC

# TODO: Change the svm model parameter and plot the result.

# your code here
for c in [1e-2, 1e-1, 0.5, 1, 10, 100, 1000, 1e3]:
    lsvm = LinearSVC(C=c, loss='hinge')
    lsvm.fit(X, y)
    w = lsvm.coef_[0]
    b = lsvm.intercept_
    #print(w,b)
    linear_plot(X, y, w=w, b=b)
    plt.title(f'Linear SVC C={c}', size=20)
    plt.show()
# Out:
# C:\Users\Sandipan.Dey\AppData\Roaming\Python\Python37\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\Sandipan.Dey\AppData\Roaming\Python\Python37\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\Sandipan.Dey\AppData\Roaming\Python\Python37\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,

# %% [markdown]
# **Part C**: Set `C=3` and compare the results you get when using the `hinge` vs the `squared_hinge` values for the `loss` parameter.  In this week's Peer Review Assignment: Explain your observations. Compare hinge loss vs. squared hinge loss.

# %%
from sklearn.svm import LinearSVC

# TODO: Train the model and get the parameters, pay attention to the loss parameter
# your code here

C = 3
for loss in ['hinge', 'squared_hinge']:
    lsvm = LinearSVC(C=C, loss=loss)
    lsvm.fit(X, y)
    w = lsvm.coef_[0]
    b = lsvm.intercept_
    #print(w,b)
    linear_plot(X, y, w=w, b=b)
    plt.title(f'Linear SVC C={C}, loss={loss}', size=20)
    plt.show()

# %% [markdown]
# **Part D**: In general, how does the choice of `C` affect the bias and variance of the model? Write your answer in this week's Peer Review assignment.

# %%
# testing cell 
# your code here

# %% [markdown]
# ### Part 3: Nonlinear SVM, Parameter Tuning, Accuracy, and Cross-Validation
# ***
#
# Any support vector machine classifier will have at least one parameter that needs to be tuned based on the training data.  The guaranteed parameter is the $C$ associated with the slack variables in the primal objective function, i.e.
#
# $$
# \min_{{\bf w}, b, {\bf \xi}} \frac{1}{2}\|{\bf w}\|^2 + C \sum_{i=1}^m \xi_i
# $$
#
# If you use a kernel fancier than the linear kernel then you will likely have other parameters as well. For instance in the polynomial kernel $K({\bf x}, {\bf z}) = ({\bf x}^T{\bf z} + c)^d$ you have to select the shift $c$ and the polynomial degree $d$.  Similarly the rbf kernel
#
# $$
# K({\bf x}, {\bf z}) = \exp\left[-\gamma\|{\bf x} - {\bf z}\|^2\right]
# $$
#
# has one tuning parameter, namely $\gamma$, which controls how fast the similarity measure drops off with distance between ${\bf x}$ and ${\bf z}$.
#
# For our examples we'll consider the rbf kernel, which gives us two parameters to tune, namely $C$ and $\gamma$.
#
# Consider the following two dimensional data

# %%
X, y = part3data(N=300, seed=1235)
nonlinear_plot(X, y)

# %% [markdown]
# **Part A**: We can use the method [SVC](http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html) from sklearn's `svm` module to fit an SVM with a nonlinear kernel to the data.  Go now and look at the documentation. Note that we pass the `kernel="rbr"` parameter to use the RBF kernel.  The other two parameters we'll be concerned with are `C` and the RBF parameter `gamma`.
#
# Write some code to fit an SVM with RBF kernel to the data and plot the results.  Use the parameter values `C=1` and `gamma=1`.

# %%
from sklearn.svm import SVC

nlsvm= SVC(C=1, gamma=1)
nlsvm.fit(X, y)

# your code here

nonlinear_plot(X, y, nlsvm)

# %% [markdown]
# **Part B**: In this part we'll use cross-validation to estimate the validation accuracy achieved by our model.  Experiment with the values of the hyperparameters to see if you can get a good validation accuracy. How do the choice of `C` and `gamma` affect the resulting decision boundary? Write your response in this week's Peer Review assignment.

# %%
from sklearn.model_selection import cross_val_score

# your code here

# uncomment and update nlsvm and scores
nlsvm = SVC(C=1, gamma=1)
scores = cross_val_score(nlsvm, X, y, cv=5)
print("cross-val mean-accuracy: {:.3f}".format(np.mean(scores)))
nonlinear_plot(X, y, nlsvm)

# C tuning
Cs = [0.1, 0.5, 1, 10, 100, 1000]
scores_C = []
for C in Cs:
    nlsvm = SVC(C=C, gamma=1)
    scores = cross_val_score(nlsvm, X, y, cv=5)
    score = np.mean(scores)
    scores_C.append(score)
    print("cross-val mean-accuracy: {:.3f} (C={})".format(score, C))
    nonlinear_plot(X, y, nlsvm)
    plt.title("cross-val mean-accuracy: {:.3f} (C={})".format(score, C), size=20)
    plt.show()

plt.figure(figsize=(7,5))
plt.plot(Cs, scores_C)
plt.title('Tuning paramater C', size=20)
plt.xlabel('C', size=20)
plt.ylabel('mean cross validation score', size=20)
plt.grid()
plt.show()
# Out:
# cross-val mean-accuracy: 0.920
# cross-val mean-accuracy: 0.903 (C=0.1)
# cross-val mean-accuracy: 0.910 (C=0.5)
# cross-val mean-accuracy: 0.920 (C=1)
# cross-val mean-accuracy: 0.933 (C=10)
# cross-val mean-accuracy: 0.940 (C=100)
# cross-val mean-accuracy: 0.943 (C=1000)

# %%
import pandas as pd
pd.DataFrame({'C': Cs, 'mean CV scores': scores_C})
# Out:
#         C  mean CV scores
# 0     0.1        0.903333
# 1     0.5        0.910000
# 2     1.0        0.920000
# 3    10.0        0.933333
# 4   100.0        0.940000
# 5  1000.0        0.943333

# %%
# gamma tuning
scores_gammas = []
gammas = [0.1, 0.2, 0.3, 0.5, 1]
for gamma in gammas:
    nlsvm = SVC(C=1, gamma=gamma)
    scores = cross_val_score(nlsvm, X, y, cv=5)
    score = np.mean(scores)
    scores_gammas.append(score)
    print("cross-val mean-accuracy: {:.3f} (gamma={})".format(score, gamma))
    nonlinear_plot(X, y, nlsvm)
    plt.title("cross-val mean-accuracy: {:.3f} (gamma={})".format(score, gamma), size=20)
    plt.show()

plt.figure(figsize=(7,5))
plt.plot(gammas, scores_gammas)
plt.title('Tuning paramater gamma', size=20)
plt.xlabel('gamma', size=20)
plt.ylabel('mean cross validation score', size=20)
plt.grid()
plt.show()
# Out:
# cross-val mean-accuracy: 0.907 (gamma=0.1)
# cross-val mean-accuracy: 0.910 (gamma=0.2)
# cross-val mean-accuracy: 0.910 (gamma=0.3)
# cross-val mean-accuracy: 0.920 (gamma=0.5)
# cross-val mean-accuracy: 0.920 (gamma=1)

# %% [markdown]
# **Part C**: How does the choice of **kernel** function affect the bias/variance of the model? Write your answer in this week's Peer Review assignment.

# %%
# instructor testing cell 
scores_kernels = []
kernels = ['linear', 'poly', 'rbf', 'sigmoid']
for kernel in kernels:
    nlsvm = SVC(kernel = kernel)
    scores = cross_val_score(nlsvm, X, y, cv=5)
    score = np.mean(scores)
    scores_kernels.append(score)
    print("cross-val mean-accuracy: {:.3f} (kernel={})".format(score, kernel))
    nonlinear_plot(X, y, nlsvm)
    plt.title("cross-val mean-accuracy: {:.3f} (kernel={})".format(score, kernel), size=20)
    plt.show()

plt.figure(figsize=(7,5))
plt.bar(kernels, scores_kernels)
plt.title('Tuning paramater kernel', size=20)
plt.xlabel('kernel', size=20)
plt.ylabel('mean cross validation score', size=20)
plt.grid()
plt.show()
# Out:
# cross-val mean-accuracy: 0.910 (kernel=linear)
# cross-val mean-accuracy: 0.907 (kernel=poly)
# cross-val mean-accuracy: 0.937 (kernel=rbf)
# cross-val mean-accuracy: 0.903 (kernel=sigmoid)

# %% [markdown]
# ### Part 4: Automating the Parameter Search
# ***
#
# On the previous problem we were able to choose some OK parameters just by hand-tuning.  But in real life (where time is money) it would be better to do something a little more automated.  One common thing to do is a **grid-search** over a predefined range of the parameters.  In this case you will loop over all possible combinations of parameters, estimate the accuracy of your model using K-Folds cross-validation, and then choose the parameter combination that produces the highest validation accuracy.
#
# **Part A**: Below is an experiment where we search over a logarithmic range between $2^{-5}$ and $2^{5}$ for $C$ and a range between $2^{-5}$ and $2^{5}$ for $\gamma$.  For the accuracy measure we use K-Folds CV with $K=3$.

# %%
np.logspace(-5, 5, 11, base=2)
# Out:
# array([3.125e-02, 6.250e-02, 1.250e-01, 2.500e-01, 5.000e-01, 1.000e+00,
#        2.000e+00, 4.000e+00, 8.000e+00, 1.600e+01, 3.200e+01])

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV
grid = GridSearchCV(SVC(), 
                   {'C': np.logspace(-5, 5, 11, base=2), 'gamma': np.logspace(-5, 5, 11, base=2)},
                   cv = 3,
                   verbose = 3) 
grid.fit(X, y)
res = grid.cv_results_
res['mean_test_score'], res['params']
# Out:
# Fitting 3 folds for each of 121 candidates, totalling 363 fits
# [CV 1/3] END ..........C=0.03125, gamma=0.03125;, score=0.530 total time=   0.0s
# [CV 2/3] END ..........C=0.03125, gamma=0.03125;, score=0.530 total time=   0.0s
# [CV 3/3] END ..........C=0.03125, gamma=0.03125;, score=0.520 total time=   0.0s
# [CV 1/3] END ...........C=0.03125, gamma=0.0625;, score=0.530 total time=   0.0s
# [CV 2/3] END ...........C=0.03125, gamma=0.0625;, score=0.530 total time=   0.0s
# [CV 3/3] END ...........C=0.03125, gamma=0.0625;, score=0.520 total time=   0.0s
# [CV 1/3] END ............C=0.03125, gamma=0.125;, score=0.530 total time=   0.0s
# [CV 2/3] END ............C=0.03125, gamma=0.125;, score=0.530 total time=   0.0s
# [CV 3/3] END ............C=0.03125, gamma=0.125;, score=0.520 total time=   0.0s
# [CV 1/3] END .............C=0.03125, gamma=0.25;, score=0.850 total time=   0.0s
# [CV 2/3] END .............C=0.03125, gamma=0.25;, score=0.870 total time=   0.0s
# [CV 3/3] END .............C=0.03125, gamma=0.25;, score=0.860 total time=   0.0s
# [CV 1/3] END ..............C=0.03125, gamma=0.5;, score=0.890 total time=   0.0s
# [CV 2/3] END ..............C=0.03125, gamma=0.5;, score=0.910 total time=   0.0s
# [CV 3/3] END ..............C=0.03125, gamma=0.5;, score=0.940 total time=   0.0s
# [CV 1/3] END ..............C=0.03125, gamma=1.0;, score=0.890 total time=   0.0s
# [CV 2/3] END ..............C=0.03125, gamma=1.0;, score=0.900 total time=   0.0s
# [CV 3/3] END ..............C=0.03125, gamma=1.0;, score=0.950 total time=   0.0s
# [CV 1/3] END ..............C=0.03125, gamma=2.0;, score=0.890 total time=   0.0s
# [CV 2/3] END ..............C=0.03125, gamma=2.0;, score=0.900 total time=   0.0s
# [CV 3/3] END ..............C=0.03125, gamma=2.0;, score=0.930 total time=   0.0s
# [CV 1/3] END ..............C=0.03125, gamma=4.0;, score=0.890 total time=   0.0s
# [CV 2/3] END ..............C=0.03125, gamma=4.0;, score=0.880 total time=   0.0s
# [CV 3/3] END ..............C=0.03125, gamma=4.0;, score=0.900 total time=   0.0s
# [CV 1/3] END ..............C=0.03125, gamma=8.0;, score=0.660 total time=   0.0s
# [CV 2/3] END ..............C=0.03125, gamma=8.0;, score=0.620 total time=   0.0s
# [CV 3/3] END ..............C=0.03125, gamma=8.0;, score=0.580 total time=   0.0s
# [CV 1/3] END .............C=0.03125, gamma=16.0;, score=0.530 total time=   0.0s
# [CV 2/3] END .............C=0.03125, gamma=16.0;, score=0.530 total time=   0.0s
# [CV 3/3] END .............C=0.03125, gamma=16.0;, score=0.520 total time=   0.0s
# [CV 1/3] END .............C=0.03125, gamma=32.0;, score=0.530 total time=   0.0s
# [CV 2/3] END .............C=0.03125, gamma=32.0;, score=0.530 total time=   0.0s
# [CV 1/3] END .................C=0.5, gamma=0.25;, score=0.890 total time=   0.0s
# [CV 2/3] END .................C=0.5, gamma=0.25;, score=0.900 total time=   0.0s
# [CV 3/3] END .................C=0.5, gamma=0.25;, score=0.950 total time=   0.0s
# [CV 1/3] END ..................C=0.5, gamma=0.5;, score=0.890 total time=   0.0s
# [CV 2/3] END ..................C=0.5, gamma=0.5;, score=0.900 total time=   0.0s
# [CV 3/3] END ..................C=0.5, gamma=0.5;, score=0.950 total time=   0.0s
# [CV 1/3] END ..................C=0.5, gamma=1.0;, score=0.900 total time=   0.0s
# [CV 2/3] END ..................C=0.5, gamma=1.0;, score=0.920 total time=   0.0s
# [CV 3/3] END ..................C=0.5, gamma=1.0;, score=0.950 total time=   0.0s
# [CV 1/3] END ..................C=0.5, gamma=2.0;, score=0.910 total time=   0.0s
# [CV 2/3] END ..................C=0.5, gamma=2.0;, score=0.910 total time=   0.0s
# [CV 3/3] END ..................C=0.5, gamma=2.0;, score=0.950 total time=   0.0s
# [CV 1/3] END ..................C=0.5, gamma=4.0;, score=0.910 total time=   0.0s
# [CV 2/3] END ..................C=0.5, gamma=4.0;, score=0.910 total time=   0.0s
# [CV 3/3] END ..................C=0.5, gamma=4.0;, score=0.940 total time=   0.0s
# [CV 1/3] END ..................C=0.5, gamma=8.0;, score=0.910 total time=   0.0s
# [CV 2/3] END ..................C=0.5, gamma=8.0;, score=0.940 total time=   0.0s
# [CV 3/3] END ..................C=0.5, gamma=8.0;, score=0.950 total time=   0.0s
# [CV 1/3] END .................C=0.5, gamma=16.0;, score=0.910 total time=   0.0s
# [CV 2/3] END .................C=0.5, gamma=16.0;, score=0.950 total time=   0.0s
# [CV 3/3] END .................C=0.5, gamma=16.0;, score=0.930 total time=   0.0s
# [CV 1/3] END .................C=0.5, gamma=32.0;, score=0.920 total time=   0.0s
# [CV 2/3] END .................C=0.5, gamma=32.0;, score=0.950 total time=   0.0s
# [CV 3/3] END .................C=0.5, gamma=32.0;, score=0.930 total time=   0.0s
# [CV 1/3] END ..............C=1.0, gamma=0.03125;, score=0.890 total time=   0.0s
# [CV 2/3] END ..............C=1.0, gamma=0.03125;, score=0.890 total time=   0.0s
# [CV 3/3] END ..............C=1.0, gamma=0.03125;, score=0.950 total time=   0.0s
# [CV 1/3] END ...............C=1.0, gamma=0.0625;, score=0.890 total time=   0.0s
# [CV 2/3] END ...............C=1.0, gamma=0.0625;, score=0.890 total time=   0.0s
# [CV 3/3] END ...............C=1.0, gamma=0.0625;, score=0.950 total time=   0.0s
# [CV 1/3] END ................C=1.0, gamma=0.125;, score=0.890 total time=   0.0s
# [CV 2/3] END ................C=1.0, gamma=0.125;, score=0.900 total time=   0.0s
# [CV 3/3] END ................C=1.0, gamma=0.125;, score=0.950 total time=   0.0s
# [CV 1/3] END .................C=1.0, gamma=0.25;, score=0.890 total time=   0.0s
# [CV 2/3] END .................C=1.0, gamma=0.25;, score=0.920 total time=   0.0s
# [CV 3/3] END .................C=1.0, gamma=0.25;, score=0.950 total time=   0.0s
# [CV 1/3] END ..................C=1.0, gamma=0.5;, score=0.890 total time=   0.0s
# [CV 2/3] END ..................C=1.0, gamma=0.5;, score=0.920 total time=   0.0s
# [CV 3/3] END ..................C=1.0, gamma=0.5;, score=0.950 total time=   0.0s
# [CV 1/3] END ..................C=1.0, gamma=1.0;, score=0.910 total time=   0.0s
# [CV 2/3] END
0;, score=0.910 total time=   0.0s
# [CV 2/3] END ..................C=4.0, gamma=4.0;, score=0.940 total time=   0.0s
# [CV 3/3] END ..................C=4.0, gamma=4.0;, score=0.950 total time=   0.0s
# [CV 1/3] END ..................C=4.0, gamma=8.0;, score=0.920 total time=   0.0s
# [CV 2/3] END ..................C=4.0, gamma=8.0;, score=0.940 total time=   0.0s
# [CV 3/3] END ..................C=4.0, gamma=8.0;, score=0.950 total time=   0.0s
# [CV 1/3] END .................C=4.0, gamma=16.0;, score=0.930 total time=   0.0s
# [CV 2/3] END .................C=4.0, gamma=16.0;, score=0.950 total time=   0.0s
# [CV 3/3] END .................C=4.0, gamma=16.0;, score=0.940 total time=   0.0s
# [CV 1/3] END .................C=4.0, gamma=32.0;, score=0.910 total time=   0.0s
# [CV 2/3] END .................C=4.0, gamma=32.0;, score=0.930 total time=   0.0s
# [CV 3/3] END .................C=4.0, gamma=32.0;, score=0.930 total time=   0.0s
# [CV 1/3] END ..............C=8.0, gamma=0.03125;, score=0.880 total time=   0.0s
# [CV 2/3] END ..............C=8.0, gamma=0.03125;, score=0.920 total time=   0.0s
# [CV 3/3] END ..............C=8.0, gamma=0.03125;, score=0.940 total time=   0.0s
# [CV 1/3] END ...............C=8.0, gamma=0.0625;, score=0.890 total time=   0.0s
# [CV 2/3] END ...............C=8.0, gamma=0.0625;, score=0.940 total time=   0.0s
# [CV 3/3] END ...............C=8.0, gamma=0.0625;, score=0.930 total time=   0.0s
# [CV 1/3] END ................C=8.0, gamma=0.125;, score=0.890 total time=   0.0s
# [CV 2/3] END ................C=8.0, gamma=0.125;, score=0.920 total time=   0.0s
# [CV 3/3] END ................C=8.0, gamma=0.125;, score=0.930 total time=   0.0s
# [CV 1/3] END .................C=8.0, gamma=0.25;, score=0.900 total time=   0.0s
# [CV 2/3] END .................C=8.0, gamma=0.25;, score=0.910 total time=   0.0s
# [CV 3/3] END .................C=8.0, gamma=0.25;, score=0.930 total time=   0.0s
# [CV 1/3] END ..................C=8.0, gamma=0.5;, score=0.910 total time=   0.0s
# [CV 2/3] END ..................C=8.0, gamma=0.5;, score=0.910 total time=   0.0s
# [CV 3/3] END ..................C=8.0, gamma=0.5;, score=0.930 total time=   0.0s
# [CV 1/3] END ..................C=8.0, gamma=1.0;, score=0.910 total time=   0.0s
# [CV 2/3] END ..................C=8.0, gamma=1.0;, score=0.930 total time=   0.0s
# [CV 3/3] END ..................C=8.0, gamma=1.0;, score=0.930 total time=   0.0s
# [CV 1/3] END ..................C=8.0, gamma=2.0;, score=0.910 total time=   0.0s
# [CV 2/3] END ..................C=8.0, gamma=2.0;, score=0.950 total time=   0.0s
# [CV 3/3] END ..................C=8.0, gamma=2.0;, score=0.950 total time=   0.0s
# [CV 1/3] END ..................C=8.0, gamma=4.0;, score=0.910 total time=   0.0s
# [CV 2/3] END ..................C=8.0, gamma=4.0;, score=0.950 total time=   0.0s
# [CV 3/3] END ..................C=8.0, gamma=4.0;, score=0.950 total time=   0.0s
# [CV 1/3] END ..................C=8.0, gamma=8.0;, score=0.930 total time=   0.0s
# [CV 2/3] END ..................C=8.0, gamma=8.0;, score=0.950 total time=   0.0s
# [CV 3/3] END ..................C=8.0, gamma=8.0;, score=0.950 total time=   0.0s
# [CV 1/3] END .................C=8.0, gamma=16.0;, score=0.920 total time=   0.0s
# [CV 2/3] END .................C=8.0, gamma=16.0;, score=0.940 total time=   0.0s
# [CV 3/3] END .................C=8.0, gamma=16.0;, score=0.940 total time=   0.0s
# [CV 1/3] END .................C=8.0, gamma=32.0;, score=0.910 total time=   0.0s
# [CV 2/3] END .................C=8.0, gamma=32.0;, score=0.920 total time=   0.0s
# [CV 3/3] END .................C=8.0, gamma=32.0;, score=0.920 total time=   0.0s
# [CV 1/3] END .............C=16.0, gamma=0.03125;, score=0.890 total time=   0.0s
# [CV 2/3] END .............C=16.0, gamma=0.03125;, score=0.930 total time=   0.0s
# [CV 3/3] END .............C=16.0, gamma=0.03125;, score=0.930 total time=   0.0s
# [CV 1/3] END ..............C=16.0, gamma=0.0625;, score=0.890 total time=   0.0s
# [CV 2/3] END ..............C=16.0, gamma=0.0625;, score=0.920 total time=   0.0s
# [CV 3/3] END ..............C=16.0, gamma=0.0625;, score=0.930 total time=   0.0s
# [CV 1/3] END ...............C=16.0, gamma=0.125;, score=0.900 total time=   0.0s
# [CV 2/3] END ...............C=16.0, gamma=0.125;, score=0.930 total time=   0.0s
# [CV 3/3] END ...............C=16.0, gamma=0.125;, score=0.930 total time=   0.0s
# [CV 1/3] END ................C=16.0, gamma=0.25;, score=0.910 total time=   0.0s
# [CV 2/3] END ................C=16.0, gamma=0.25;, score=0.910 total time=   0.0s
# [CV 3/3] END ................C=16.0, gamma=0.25;, score=0.930 total time=   0.0s
# [CV 1/3] END .................C=16.0, gamma=0.5;, score=0.910 total time=   0.0s
# [CV 2/3] END .................C=16.0, gamma=0.5;, score=0.920 total time=   0.0s
# [CV 3/3] END .................C=16.0, gamma=0.5;, score=0.930 total time=   0.0s
# [CV 1/3] END .................C=16.0, gamma=1.0;, score=0.910 total time=   0.0s
# [CV 2/3] END .................C=16.0, gamma=1.0;, score=0.930 total time=   0.0s
# [CV 3/3] END .................C=16.0, gamma=1.0;, score=0.930 total time=   0.0s
# [CV 1/3] END .................C=16.0, gamma=2.0;, score=0.910 total time=   0.0s
# [CV 2/3] END .................C=16.0, gamma=2.0;, score=0.950 total time=   0.0s
# [CV 3/3] END .................C=16.0, gamma=2.0;, score=0.950 total time=   0.0s
# [CV 1/3] END .................C=16.0, gamma=4.0;, score=0.920 total time=   0.0s
# [CV 2/3] END .................C=16.0, gamma=4.0;, score=0.950 total time=   0.0s
# [CV 3/3] END .................C=16.0, gamma=4.0;, score=0.940 total time=   0.0s
# [CV 1/3] END .................C=16.0, gamma=8.0;, score=0.940 total time=   0.0s
# [CV 2/3] END .................C=16.0, gamma=8.0;, score=0.950 total time=   0.0s
# [CV 3/3] END .................C=16.0, gamma=8.0;, score=0.940 total time=   0.0s
# [CV 1/3] END ................C=16.0, gamma=16.0;, score=0.910 total time=   0.0s
# [CV 2/3] END ................C=16.0, gamma=16.0;, score=0.930 total time=   0.0s
# [CV 3/3] END ................C=16.0, gamma=16.0;, score=0.920 total time=   0.0s
# [CV 1/3] END ................C=16.0, gamma=32.0;, score=0.930 total time=   0.0s
# [CV 2/3] END ................C=16.0, gamma=32.0;, score=0.920 total time=   0.0s
# [CV 3/3] END ................C=16.0, gamma=32.0;, score=0.910 total time=   0.0s
# [CV 1/3] END .............C=32.0, gamma=0.03125;, score=0.890 total time=   0.0s
# [CV 2/3] END .............C=32.0, gamma=0.03125;, score=0.920 total time=   0.0s
# [CV 3/3] END .............C=32.0, gamma=0.03125;, score=0.930 total time=   0.0s
# [CV 1/3] END ..............C=32.0, gamma=0.0625;, score=0.900 total time=   0.0s
# [CV 2/3] END ..............C=32.0, gamma=0.0625;, score=0.930 total time=   0.0s
# [CV 3/3] END ..............C=32.0, gamma=0.0625;, score=0.930 total time=   0.0s
# [CV 1/3] END ...............C=32.0, gamma=0.125;, score=0.910 total time=   0.0s
# [CV 2/3] END ...............C=32.0, gamma=0.125;, score=0.920 total time=   0.0s
# [CV 3/3] END ...............C=32.0, gamma=0.125;, score=0.930 total time=   0.0s
# [CV 1/3] END ................C=32.0, gamma=0.25;, score=0.900 total time=   0.0s
# [CV 2/3] END ................C=32.0, gamma=0.25;, score=0.900 total time=   0.0s
# [CV 3/3] END ................C=32.0, gamma=0.25;, score=0.930 total time=   0.0s
# [CV 1/3] END .................C=32.0, gamma=0.5;, score=0.910 total time=   0.0s
# [CV 2/3] END .................C=32.0, gamma=0.5;, score=0.920 total time=   0.0s
# [CV 3/3] END .................C=32.0, gamma=0.5;, score=0.930 total time=   0.0s
# [CV 1/3] END .................C=32.0, gamma=1.0;, score=0.910 total time=   0.0s
# [CV 2/3] END .................C=32.0, gamma=1.0;, score=0.930 total time=   0.0s
# [CV 3/3] END .................C=32.0, gamma=1.0;, score=0.930 total time=   0.0s
# [CV 1/3] END .................C=32.0, gamma=2.0;, score=0.920 total time=   0.0s
# [CV 2/3] END .................C=32.0, gamma=2.0;, score=0.950 total time=   0.0s
# [CV 3/3] END .................C=32.0, gamma=2.0;, score=0.960 total time=   0.0s
# [CV 1/3] END .................C=32.0, gamma=4.0;, score=0.930 total time=   0.0s
# [CV 2/3] END .................C=32.0, gamma=4.0;, score=0.950 total time=   0.0s
# [CV 3/3] END .................C=32.0, gamma=4.0;, score=0.930 total time=   0.0s
# [CV 1/3] END .................C=32.0, gamma=8.0;, score=0.930 total time=   0.0s
# [CV 2/3] END .................C=32.0, gamma=8.0;, score=0.930 total time=   0.0s
# [CV 3/3] END .................C=32.0, gamma=8.0;, score=0.940 total time=   0.0s
# [CV 1/3] END ................C=32.0, gamma=16.0;, score=0.920 total time=   0.0s
# [CV 2/3] END ................C=32.0, gamma=16.0;, score=0.930 total time=   0.0s
# [CV 3/3] END ................C=32.0, gamma=16.0;, score=0.910 total time=   0.0s
# [CV 1/3] END ................C=32.0, gamma=32.0;, score=0.930 total time=   0.0s
# [CV 2/3] END ................C=32.0, gamma=32.0;, score=0.940 total time=   0.0s
# [CV 3/3] END ................C=32.0, gamma=32.0;, score=0.900 total time=   0.0s
# (array([0.52666667, 0.52666667, 0.52666667, 0.86      , 0.91333333,
#         0.91333333, 0.90666667, 0.89      , 0.62      , 0.52666667,
#         0.52666667, 0.52666667, 0.57      , 0.90666667, 0.91333333,
#         0.90666667, 0.91      , 0.91      , 0.90333333, 0.92      ,
#         0.71333333, 0.52666667, 0.6       , 0.90666667, 0.91      ,
#         0.90666667, 0.91      , 0.91      , 0.91      , 0.91333333,
#         0.92      , 0.93333333, 0.78333333, 0.91      , 0.91      ,
#         0.91      , 0.91      , 0.91333333, 0.91333333, 0.91666667,
#         0.91666667, 0.92666667, 0.92666667, 0.93333333, 0.90666667,
#         0.91333333, 0.91      , 0.91333333, 0.91333333, 0.92333333,
#         0.92333333, 0.92      , 0.93333333, 0.93      , 0.93333333,
#         0.91      , 0.91      , 0.91333333, 0.92      , 0.92      ,
#         0.92333333, 0.92      , 0.93      , 0.92666667, 0.94      ,
#         0.93333333, 0.91      , 0.91333333, 0.91333333, 0.92333333,
#         0.91666667, 0.91666667, 0.91666667, 0.93      , 0.94      ,
#         0.93333333, 0.92666667, 0.91      , 0.91666667, 0.92      ,
#         0.91333333, 0.91666667, 0.91      , 0.93      , 0.93333333,
#         0.93666667, 0.94      , 0.92333333, 0.91333333, 0.92      ,
#         0.91333333, 0.91333333, 0.91666667, 0.92333333, 0.93666667,
#         0.93666667, 0.94333333, 0.93333333, 0.91666667, 0.91666667,
#         0.91333333, 0.92      , 0.91666667, 0.92      , 0.92333333,
#         0.93666667, 0.93666667, 0.94333333, 0.92      , 0.92      ,
#         0.91333333, 0.92      , 0.92      , 0.91      , 0.92      ,
#         0.92333333, 0.94333333, 0.93666667, 0.93333333, 0.92      ,
#         0.92333333]),
#  [{'C': 0.03125, 'gamma': 0.03125},
#   {'C': 0.03125, 'gamma': 0.0625},
#   {'C': 0.03125, 'gamma': 0.125},
#   {'C': 0.03125, 'gamma': 0.25},
#   {'C': 0.03125, 'gamma': 0.5},
#   {'C': 0.03125, 'gamma': 1.0},
#   {'C': 0.03125, 'gamma': 2.0},
#   {'C': 0.03125, 'gamma': 4.0},
#   {'C': 0.03125, 'gamma': 8.0},
#   {'C': 0.03125, 'gamma': 16.0},
#   {'C': 0.03125, 'gamma': 32.0},
#   {'C': 0.0625, 'gamma': 0.03125},
#   {'C': 0.0625, 'gamma': 0.0625},
#   {'C': 0.0625, 'gamma': 0.125},
#   {'C': 0.0625, 'gamma': 0.25},
#   {'C': 0.0625, 'gamma': 0.5},
#   {'C': 0.0625, 'gamma': 1.0},
#   {'C': 0.0625, 'gamma': 2.0},
#   {'C': 0.0625, 'gamma': 4.0},
#   {'C': 0.0625, 'gamma': 8.0},
#   {'C': 0.0625, 'gamma': 16.0},
#   {'C': 0.0625, 'gamma': 32.0},
#   {'C': 0.125, 'gamma': 0.03125},
#   {'C': 0.125, 'gamma': 0.0625},
#   {'C': 0.125, 'gamma': 0.125},
#   {'C': 0.125, 'gamma': 0.25},
#   {'C': 0.125, 'gamma': 0.5},
#   {'C': 0.125, 'gamma': 1.0},
#   {'C': 0.125, 'gamma': 2.0},
#   {'C': 0.125, 'gamma': 4.0},
#   {'C': 0.125, 'gamma': 8.0},
#   {'C': 0.125, 'gamma': 16.0},
#   {'C': 0.125, 'gamma': 32.0},
#   {'C': 0.25, 'gamma': 0.03125},
#   {'C': 0.25, 'gamma': 0.0625},
#   {'C': 0.25, 'gamma': 0.125},
#   {'C': 0.25, 'gamma': 0.25},
#   {'C': 0.25, 'gamma': 0.5},
#   {'C': 0.25, 'gamma': 1.0},
#   {'C': 0.25, 'gamma': 2.0},
#   {'C': 0.25, 'gamma': 4.0},
#   {'C': 0.25, 'gamma': 8.0},
#   {'C': 0.25, 'gamma': 16.0},
#   {'C': 0.25, 'gamma': 32.0},
#   {'C': 0.5, 'gamma': 0.03125},
#   {'C': 0.5, 'gamma': 0.0625},
#   {'C': 0.5, 'gamma': 0.125},
#   {'C': 0.5, 'gamma': 0.25},
#   {'C': 0.5, 'gamma': 0.5},
#   {'C': 0.5, 'gamma': 1.0},
#   {'C': 0.5, 'gamma': 2.0},
#   {'C': 0.5, 'gamma': 4.0},
#   {'C': 0.5, 'gamma': 8.0},
#   {'C': 0.5, 'gamma': 16.0},
#   {'C': 0.5, 'gamma': 32.0},
#   {'C': 1.0, 'gamma': 0.03125},
#   {'C': 1.0, 'gamma': 0.0625},
#   {'C': 1.0, 'gamma': 0.125},
#   {'C': 1.0, 'gamma': 0.25},
#   {'C': 1.0, 'gamma': 0.5},
#   {'C': 1.0, 'gamma': 1.0},
#   {'C': 1.0, 'gamma': 2.0},
#   {'C': 1.0, 'gamma': 4.0},
#   {'C': 1.0, 'gamma': 8.0},
#   {'C': 1.0, 'gamma': 16.0},
#   {'C': 1.0, 'gamma': 32.0},
#   {'C': 2.0, 'gamma': 0.03125},
#   {'C': 2.0, 'gamma': 0.0625},
#   {'C': 2.0, 'gamma': 0.125},
#   {'C': 2.0, 'gamma': 0.25},
#   {'C': 2.0, 'gamma': 0.5},
#   {'C': 2.0, 'gamma': 1.0},
#   {'C': 2.0, 'gamma': 2.0},
#   {'C': 2.0, 'gamma': 4.0},
#   {'C': 2.0, 'gamma': 8.0},
#   {'C': 2.0, 'gamma': 16.0},
#   {'C': 2.0, 'gamma': 32.0},
#   {'C': 4.0, 'gamma': 0.03125},
#   {'C': 4.0, 'gamma': 0.0625},
#   {'C': 4.0, 'gamma': 0.125},
#   {'C': 4.0, 'gamma': 0.25},
#   {'C': 4.0, 'gamma': 0.5},
#   {'C': 4.0, 'gamma': 1.0},
#   {'C': 4.0, 'gamma': 2.0},
#   {'C': 4.0, 'gamma': 4.0},
#   {'C': 4.0, 'gamma': 8.0},
#   {'C': 4.0, 'gamma': 16.0},
#   {'C': 4.0, 'gamma': 32.0},
#   {'C': 8.0, 'gamma': 0.03125},
#   {'C': 8.0, 'gamma': 0.0625},
#   {'C': 8.0, 'gamma': 0.125},
#   {'C': 8.0, 'gamma': 0.25},
#   {'C': 8.0, 'gamma': 0.5},
#   {'C': 8.0, 'gamma': 1.0},
#   {'C': 8.0, 'gamma': 2.0},
#   {'C': 8.0, 'gamma': 4.0},
#   {'C': 8.0, 'gamma': 8.0},
#   {'C': 8.0, 'gamma': 16.0},
#   {'C': 8.0, 'gamma': 32.0},
#   {'C': 16.0, 'gamma': 0.03125},
#   {'C': 16.0, 'gamma': 0.0625},
#   {'C': 16.0, 'gamma': 0.125},
#   {'C': 16.0, 'gamma': 0.25},
#   {'C': 16.0, 'gamma': 0.5},
#   {'C': 16.0, 'gamma': 1.0},
#   {'C': 16.0, 'gamma': 2.0},
#   {'C': 16.0, 'gamma': 4.0},
#   {'C': 16.0, 'gamma': 8.0},
#   {'C': 16.0, 'gamma': 16.0},
#   {'C': 16.0, 'gamma': 32.0},
#   {'C': 32.0, 'gamma': 0.03125},
#   {'C': 32.0, 'gamma': 0.0625},
#   {'C': 32.0, 'gamma': 0.125},
#   {'C': 32.0, 'gamma': 0.25},
#   {'C': 32.0, 'gamma': 0.5},
#   {'C': 32.0, 'gamma': 1.0},
#   {'C': 32.0, 'gamma': 2.0},
#   {'C': 32.0, 'gamma': 4.0},
#   {'C': 32.0, 'gamma': 8.0},
#   {'C': 32.0, 'gamma': 16.0},
#   {'C': 32.0, 'gamma': 32.0}])

# %% [markdown]
# **Part B**: The following function will plot a heat-map of the cross-validation accuracies for each combination of parameters.  Which combination looks the best? Enter your response in this week's Peer Review assignment.

# %%
plotSearchGrid(grid)

# %%
import seaborn as sns
sns.set(font_scale=1.2)
scores = [x for x in grid.cv_results_["mean_test_score"]]
scores = np.array(scores).reshape(len(grid.param_grid["C"]), len(grid.param_grid["gamma"]))
scores
plt.figure(figsize=(15,12))
ax = sns.heatmap(scores, annot=True, fmt=".3f", linewidth=0.5)
ax.set_xticklabels(grid.param_grid["gamma"])
ax.set_yticklabels(grid.param_grid["C"])
ax.set_xlabel('gamma')
ax.set_ylabel('C')
plt.title('Validation Accuracy', size=20)
plt.show()

# %%
# print best paramters and best accuracy 
scores = [x for x in grid.cv_results_["mean_test_score"]]
scores = np.array(scores).reshape(len(grid.param_grid["C"]), len(grid.param_grid["gamma"]))
max_acc_scores = scores.max()
max_acc_indices = np.where(scores==scores.max()) #np.argwhere(scores==scores.max())
gammas = grid.param_grid["gamma"][max_acc_indices[0]]
Cs = grid.param_grid["C"][max_acc_indices[0]]
print(f'max accuracy score = {scores.max()}')
# combination of hyperparameter values where the highest mean CV accuracy is obtained
for gamma, C in zip(gammas, Cs): 
    print(f'gamma = {gamma}, C = {C}')
# Out:
# max accuracy score = 0.9433333333333334
# gamma = 8.0, C = 8.0
# gamma = 16.0, C = 16.0
# gamma = 32.0, C = 32.0

# %% [markdown]
# **Part C**: The GridSearchCV object scores, among other things, the best combination of parameters as well as the cross-validation accuracy achieved with those parameters.  Print those quantities for our model.

# %%
# best estimator
nlsvm = SVC(C=8, gamma=8)
nonlinear_plot(X, y, nlsvm)
plt.title('Best Validation Accuracy with C=8, gamma=8', size=20)
plt.show()

# %% [markdown]
# **Part D [Peer Review]**: The GridSearchCV object also stores the classifier trained with the best hyperparameters.  Pass this best estimator into the `nonlinear_plot` function to view the best decision boundary. Answer the Peer Review questions for this section. What can you tell about the best decision boundary?

# %%
# pass GridSearchCV object best estimator into nonlinear_plot
# your code here
