# %% [markdown]
# ### WARNING
# Please refrain from using **print statements/anything that dumps large outputs(>500 lines) to STDOUT** to avoid running to into **memory issues**.
# Doing so requires your entire lab to be reset which may also result in loss of progress and you will be required to reach out to Coursera for assistance with this.
# This process usually takes time causing delays to your submission.

# %% [markdown]
# ### Validate Button
# Please note that this assignment uses nbgrader to facilitate grading. You will see a **validate button** at the top of your Jupyter notebook. If you hit this button, it will run tests cases for the lab that aren't hidden. It is good to use the validate button before submitting the lab. Do know that the labs in the course contain hidden test cases. The validate button will not let you know whether these test cases pass. After submitting your lab, you can see more information about these hidden test cases in the Grader Output. <br>
# ***Cells with longer execution times will cause the validate button to time out and freeze. Please know that if you run into Validate time-outs, it will not affect the final submission grading.*** <br>

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Set color map to have light blue background
sns.set()
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %% [markdown]
# N.B.: I recommend that you use the `statsmodel` library to do the regression analysis as opposed to *e.g.* `sklearn`. The `sklearn` library is great for advanced topics, but it's easier to get lost in a sea of details and it's not needed for these problems.

# %% [markdown]
# # 1.  Polynomial regression using MPG data [25 pts, Peer Review]
# We will be using Auto MPG data from UCI datasets (https://archive.ics.uci.edu/ml/datasets/Auto+MPG) to study polynomial regression.

# %%
columns = ['mpg','cylinders','displacement','horsepower','weight','acceleration','model_year','origin','car_name']
df = pd.read_csv("data/auto-mpg.data", header=None, delimiter=r"\s+", names=columns) 
print(df.info())
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car_name      398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB
# None
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# ### 1a) Clean the data [5 pts]
#
# 1. Fix data types
# 2. Remove null or undefined values
# 3. Drop the column car_name
#
# Replace the data frame with the cleaned data frame. Do not change the column names, and do not add new columns.
#
# Hint: 1. Dtype of one column is incorrect.

# %%
# replace data frame with cleaned data frame
# fix data types, remove null or undefined values, drop the column car_name
# NOTE: do not change the column names or add new columns 
# your code here
# df.isna().any(axis=1)
df = df.dropna()
df['horsepower'] = df['horsepower'].astype('str')
df = df[~(df["horsepower"] == '?')]
df['horsepower'] = df['horsepower'].astype('float')
df = df.drop(columns=['car_name'])
#df.shape
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year  origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
# this cell will test that you properly cleaned the dataframe

# %% [markdown]
# ### 1b) Fit a simple linear regression model with a feature that maximizes $R^2$. [5 pts]
# Which feature is the best predictor, and the resulting r-squared value? Update your answer below.

# %%
# your code here

features = df.columns.values
y = df['mpg'].values

best_predictor, best_r_squared = None, 0
for feature in features[1:]:
    x = df[feature].values
    x = sm.add_constant(x)
    log_reg = sm.OLS(y, x)
    res = log_reg.fit() 
    if res.rsquared > best_r_squared:
        best_predictor, best_r_squared = feature, res.rsquared
    #print(res.rsquared)
        
#print(best_predictor, best_r_squared)
#best_predictor=''
#best_r_squared=0

# %%
# this cell will test best_predictor and best_r_squared

# %% [markdown]
# ### 1c) Using the feature found above (without normalizing), fit polynomial regression up to N=10 and report $R^2$. Which polynomial degree gives the best result? [10 pts]
# Hint: For N-degree polynomial fit, **you have to include all orders upto N**. Use a for loop instead of running it manually. The `statsmodels.formula.api` formula string can understand **`np.power(x,n)`** function to include a feature representing $x^n$.
#
# For example, the formula for n = 4 ---> mpg ~ weight + np.power(weight,2) + np.power(weight,3) + np.power(weight,4)

# %%
# return updated best_degree and best_r_squared 
best_degree = 1
best_r_squared = 0
# your code here
formula_str = 'mpg ~ weight'
mod = smf.ols(formula=formula_str, data=df)
res = mod.fit()
best_degree = 1
best_r_squared = res.rsquared     
for deg in range(2, 11):
    formula_str += f' + np.power(weight, {deg})'
    mod = smf.ols(formula=formula_str, data=df)
    res = mod.fit()
    #print(res.summary())
    #print(deg, res.rsquared)
    if res.rsquared > best_r_squared:
        best_r_squared, best_degree = res.rsquared, deg

#print(best_r_squared, best_degree)

# %%
# this cell tests best_degree and best_r_squared

# %% [markdown]
# ### 1d) Now, let's make a new feature called 'weight_norm' which is weight normalized by the mean value. [5 pts]
# Run training with polynomial models with polynomial degrees up to 20. Print out each polynomial degree and $R^2$ value. What do you observe from the result? What are the best_degree and best_r_qaured just based on $R^2$ value?
# Inspect model summary from each model. What is the highest order model that makes sense (fill the value for the sound_degree)?
#
# Note: For N-degree polynomial fit, you have to include all orders upto N.

# %%
# best_degree = 1
# best_r_squared = 0 
# sound_degree = 1

df['weight_norm'] = df['weight']/df['weight'].mean()
# your code here
formula_str = 'mpg ~ weight_norm'
print(formula_str)
mod = smf.ols(formula=formula_str, data=df).fit()
deg = 1
best_degree = deg
best_r_squared = mod.rsquared     
r_squareds = [best_r_squared]
r_squared_adjs = [mod.rsquared_adj]
print('{:2d} {:.04f} {:.04f}'.format(deg, mod.rsquared, mod.rsquared_adj))
print(mod.summary())
for deg in range(2, 21):
    formula_str += f' + np.power(weight_norm, {deg})'
    mod = smf.ols(formula=formula_str, data=df).fit()
    print('{:2d} {:.04f} {:.04f}'.format(deg, mod.rsquared, mod.rsquared_adj))
    print(formula_str)
    print(mod.summary())
    r_squareds.append(mod.rsquared)
    r_squared_adjs.append(mod.rsquared_adj)
    if mod.rsquared > best_r_squared:
        best_r_squared, best_degree = mod.rsquared, deg

#plt.figure(figsize=(10,10))
#plt.plot(range(1,21), r_squareds, label=r'$R^2$')
#plt.plot(range(1,21), r_squared_adjs, label=r'$adjusted R^2$')
#plt.xticks(range(1,21))
#plt.legend()
#plt.show()

sound_degree = 3 #7 #2 #11 #14
#best_degree, best_degree
# Out:
# mpg ~ weight_norm
#  1 0.6926 0.6918
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.693
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     878.8
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):          6.02e-102
# Time:                        03:40:24   Log-Likelihood:                -1130.0
# No. Observations:                 392   AIC:                             2264.
# Df Residuals:                     390   BIC:                             2272.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      46.2165      0.799     57.867      0.000      44.646      47.787
# weight_norm   -22.7706      0.768    -29.645      0.000     -24.281     -21.260
# ==============================================================================
# Omnibus:                       41.682   Durbin-Watson:                   0.808
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.039
# Skew:                           0.727   Prob(JB):                     9.18e-14
# Kurtosis:                       4.251   Cond. No.                         7.17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  2 0.7151 0.7137
# mpg ~ weight_norm + np.power(weight_norm, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.715
# Model:                            OLS   Adj. R-squared:                  0.714
# Method:                 Least Squares   F-statistic:                     488.3
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):          8.39e-107
# Time:                        03:40:24   Log-Likelihood:                -1115.1
# No. Observations:                 392   AIC:                             2236.
# Df Residuals:                     389   BIC:                             2248.
# Df Model:                           2
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   62.2555      2.993     20.800      0.000      56.371      68.140
# weight_norm                -55.0722      5.872     -9.379      0.000     -66.617     -43.527
# np.power(weight_norm, 2)    15.0418      2.713      5.545      0.000       9.709      20.375
# ==============================================================================
# Omnibus:                       53.804   Durbin-Watson:                   0.770
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.923
# Skew:                           0.809   Prob(JB):                     4.03e-21
# Kurtosis:                       4.770   Cond. No.                         62.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  3 0.7151 0.7129
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.715
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     324.7
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):          2.09e-105
# Time:                        03:40:24   Log-Likelihood:                -1115.1
# No. Observations:                 392   AIC:                             2238.
# Df Residuals:                     388   BIC:                             2254.
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   61.6952     11.043      5.587      0.000      39.984      83.407
# weight_norm                -53.3874     32.500     -1.643      0.101    -117.285      10.510
# np.power(weight_norm, 2)    13.4357     30.592      0.439      0.661     -46.710      73.582
# np.power(weight_norm, 3)     0.4874      9.247      0.053      0.958     -17.692      18.667
# ==============================================================================
# Omnibus:                       53.711   Durbin-Watson:                   0.770
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.724
# Skew:                           0.808   Prob(JB):                     4.45e-21
# Kurtosis:                       4.768   Cond. No.                         540.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  4 0.7155 0.7125
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.715
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     243.3
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):          3.27e-104
# Time:                        03:40:24   Log-Likelihood:                -1114.8
# No. Observations:                 392   AIC:                             2240.
# Df Residuals:                     387   BIC:                             2260.
# Df Model:                           4
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   36.8538     38.636      0.954      0.341     -39.109     112.817
# weight_norm                 46.0811    151.766      0.304      0.762    -252.309     344.471
# np.power(weight_norm, 2)  -130.3063    216.399     -0.602      0.547    -555.771     295.158
# np.power(weight_norm, 3)    89.4576    132.917      0.673      0.501    -171.872     350.788
# np.power(weight_norm, 4)   -19.9560     29.741     -0.671      0.503     -78.430      38.518
# ==============================================================================
# Omnibus:                       53.250   Durbin-Watson:                   0.767
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.572
# Skew:                           0.799   Prob(JB):                     4.80e-21
# Kurtosis:                       4.782   Cond. No.                     4.68e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.68e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#  5 0.7161 0.7124
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.716
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     194.7
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):          3.59e-103
# Time:                        03:40:24   Log-Likelihood:                -1114.4
# No. Observations:                 392   AIC:                             2241.
# Df Residuals:                     386   BIC:                             2265.
# Df Model:                           5
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                  -80.8344    134.290     -0.602      0.548    -344.867     183.198
# weight_norm                639.8446    666.387      0.960      0.338    -670.358    1950.047
# np.power(weight_norm, 2) -1291.1196   1286.875     -1.003      0.316   -3821.281    1239.041
# np.power(weight_norm, 3)  1189.1977   1209.132      0.984      0.326   -1188.111    3566.506
# np.power(weight_norm, 4)  -525.5006    553.262     -0.950      0.343   -1613.284     562.283
# np.power(weight_norm, 5)    90.3757     98.763      0.915      0.361    -103.805     284.556
# ==============================================================================
# Omnibus:                       52.577   Durbin-Watson:                   0.764
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               92.901
# Skew:                           0.788   Prob(JB):                     6.71e-21
# Kurtosis:                       4.790   Cond. No.                     4.36e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.36e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#  6 0.7166 0.7121
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.717
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     162.2
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):          3.84e-102
# Time:                        03:40:24   Log-Likelihood:                -1114.1
# No. Observations:                 392   AIC:                             2242.
# Df Residuals:                     385   BIC:                             2270.
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 -429.2032    457.407     -0.938      0.349   -1328.532     470.125
# weight_norm               2766.6708   2751.333      1.006      0.315   -2642.849    8176.191
# np.power(weight_norm, 2) -6555.5555   6731.550     -0.974      0.331   -1.98e+04    6679.646
# np.power(weight_norm, 3)  7954.0686   8576.189      0.927      0.354   -8907.961    2.48e+04
# np.power(weight_norm, 4) -5289.0658   6004.217     -0.881      0.379   -1.71e+04    6516.094
# np.power(weight_norm, 5)  1835.1712   2192.083      0.837      0.403   -2474.782    6145.124
# np.power(weight_norm, 6)  -260.0591    326.395     -0.797      0.426    -901.798     381.680
# ==============================================================================
# Omnibus:                       51.551   Durbin-Watson:                   0.769
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               90.102
# Skew:                           0.779   Prob(JB):                     2.72e-20
# Kurtosis:                       4.758   Cond. No.                     4.19e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.19e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#  7 0.7178 0.7126
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6) + np.power(weight_norm, 7)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.718
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     139.5
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):          2.23e-101
# Time:                        03:40:24   Log-Likelihood:                -1113.2
# No. Observations:                 392   AIC:                             2242.
# Df Residuals:                     384   BIC:                             2274.
# Df Model:                           7
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                -2354.7912   1560.446     -1.509      0.132   -5422.880     713.298
# weight_norm               1.651e+04    1.1e+04      1.501      0.134   -5111.991    3.81e+04
# np.power(weight_norm, 2) -4.757e+04   3.25e+04     -1.464      0.144   -1.11e+05    1.63e+04
# np.power(weight_norm, 3)  7.436e+04   5.22e+04      1.426      0.155   -2.82e+04    1.77e+05
# np.power(weight_norm, 4) -6.833e+04   4.92e+04     -1.388      0.166   -1.65e+05    2.84e+04
# np.power(weight_norm, 5)  3.695e+04   2.73e+04      1.354      0.177   -1.67e+04    9.06e+04
# np.power(weight_norm, 6)  -1.09e+04   8247.471     -1.321      0.187   -2.71e+04    5320.029
# np.power(weight_norm, 7)  1353.0270   1048.380      1.291      0.198    -708.256    3414.310
# ==============================================================================
# Omnibus:                       51.813   Durbin-Watson:                   0.781
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.789
# Skew:                           0.786   Prob(JB):                     3.18e-20
# Kurtosis:                       4.740   Cond. No.                     4.11e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.11e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#  8 0.7178 0.7119
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6) + np.power(weight_norm, 7) + np.power(weight_norm, 8)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.718
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     121.8
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):          2.72e-100
# Time:                        03:40:24   Log-Likelihood:                -1113.2
# No. Observations:                 392   AIC:                             2244.
# Df Residuals:                     383   BIC:                             2280.
# Df Model:                           8
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                -2968.4601   5187.274     -0.572      0.567   -1.32e+04    7230.640
# weight_norm               2.153e+04    4.2e+04      0.513      0.608    -6.1e+04    1.04e+05
# np.power(weight_norm, 2)  -6.52e+04   1.46e+05     -0.447      0.655   -3.52e+05    2.22e+05
# np.power(weight_norm, 3)   1.09e+05   2.84e+05      0.384      0.701   -4.49e+05    6.67e+05
# np.power(weight_norm, 4) -1.099e+05   3.39e+05     -0.324      0.746   -7.76e+05    5.56e+05
# np.power(weight_norm, 5)  6.827e+04   2.54e+05      0.269      0.788   -4.31e+05    5.68e+05
# np.power(weight_norm, 6) -2.536e+04   1.17e+05     -0.217      0.828   -2.55e+05    2.04e+05
# np.power(weight_norm, 7)  5097.9849   3.02e+04      0.169      0.866   -5.43e+04    6.45e+04
# np.power(weight_norm, 8)  -416.7308   3358.984     -0.124      0.901   -7021.089    6187.627
# ==============================================================================
# Omnibus:                       52.013   Durbin-Watson:                   0.783
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               90.251
# Skew:                           0.788   Prob(JB):                     2.52e-20
# Kurtosis:                       4.744   Cond. No.                     4.07e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.91e-11. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#  9 0.7182 0.7116
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6) + np.power(weight_norm, 7) + np.power(weight_norm, 8) + np.power(weight_norm, 9)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.718
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     108.2
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           2.36e-99
# Time:                        03:40:24   Log-Likelihood:                -1112.9
# No. Observations:                 392   AIC:                             2246.
# Df Residuals:                     382   BIC:                             2286.
# Df Model:                           9
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 9896.1067    1.8e+04      0.549      0.584   -2.56e+04    4.54e+04
# weight_norm              -9.741e+04   1.65e+05     -0.590      0.556   -4.22e+05    2.27e+05
# np.power(weight_norm, 2)  4.141e+05    6.6e+05      0.627      0.531   -8.84e+05    1.71e+06
# np.power(weight_norm, 3) -9.961e+05   1.51e+06     -0.659      0.510   -3.97e+06    1.97e+06
# np.power(weight_norm, 4)  1.497e+06   2.18e+06      0.685      0.494    -2.8e+06    5.79e+06
# np.power(weight_norm, 5) -1.461e+06   2.07e+06     -0.706      0.481   -5.53e+06    2.61e+06
# np.power(weight_norm, 6)  9.275e+05   1.29e+06      0.722      0.471    -1.6e+06    3.45e+06
# np.power(weight_norm, 7)   -3.7e+05   5.05e+05     -0.733      0.464   -1.36e+06    6.22e+05
# np.power(weight_norm, 8)  8.429e+04   1.14e+05      0.741      0.459   -1.39e+05    3.08e+05
# np.power(weight_norm, 9) -8365.4797   1.12e+04     -0.745      0.457   -3.05e+04    1.37e+04
# ==============================================================================
# Omnibus:                       50.843   Durbin-Watson:                   0.777
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.844
# Skew:                           0.779   Prob(JB):                     1.39e-19
# Kurtosis:                       4.700   Cond. No.                     4.31e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.28e-12. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 10 0.7199 0.7125
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6) + np.power(weight_norm, 7) + np.power(weight_norm, 8) + np.power(weight_norm, 9) + np.power(weight_norm, 10)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.720
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     97.92
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           8.13e-99
# Time:                        03:40:24   Log-Likelihood:                -1111.8
# No. Observations:                 392   AIC:                             2246.
# Df Residuals:                     381   BIC:                             2289.
# Df Model:                          10
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                  1.047e+05   6.52e+04      1.606      0.109   -2.35e+04    2.33e+05
# weight_norm               -1.071e+06   6.64e+05     -1.612      0.108   -2.38e+06    2.35e+05
# np.power(weight_norm, 2)   4.839e+06      3e+06      1.614      0.107   -1.06e+06    1.07e+07
# np.power(weight_norm, 3)   -1.27e+07   7.88e+06     -1.611      0.108   -2.82e+07     2.8e+06
# np.power(weight_norm, 4)   2.147e+07   1.34e+07      1.605      0.109   -4.84e+06    4.78e+07
# np.power(weight_norm, 5)  -2.444e+07   1.53e+07     -1.594      0.112   -5.46e+07     5.7e+06
# np.power(weight_norm, 6)   1.899e+07    1.2e+07      1.582      0.115   -4.62e+06    4.26e+07
# np.power(weight_norm, 7)  -9.949e+06   6.35e+06     -1.566      0.118   -2.24e+07    2.54e+06
# np.power(weight_norm, 8)   3.367e+06   2.17e+06      1.550      0.122   -9.05e+05    7.64e+06
# np.power(weight_norm, 9)  -6.651e+05   4.34e+05     -1.532      0.126   -1.52e+06    1.89e+05
# np.power(weight_norm, 10)  5.828e+04   3.85e+04      1.513      0.131   -1.75e+04    1.34e+05
# ==============================================================================
# Omnibus:                       51.509   Durbin-Watson:                   0.772
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.045
# Skew:                           0.787   Prob(JB):                     7.61e-20
# Kurtosis:                       4.706   Cond. No.                     4.78e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.6e-14. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 11 0.7209 0.7128
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6) + np.power(weight_norm, 7) + np.power(weight_norm, 8) + np.power(weight_norm, 9) + np.power(weight_norm, 10) + np.power(weight_norm, 11)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     89.23
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           4.16e-98
# Time:                        03:40:24   Log-Likelihood:                -1111.1
# No. Observations:                 392   AIC:                             2246.
# Df Residuals:                     380   BIC:                             2294.
# Df Model:                          11
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                  3.816e+05   2.44e+05      1.564      0.119   -9.81e+04    8.61e+05
# weight_norm               -4.206e+06   2.74e+06     -1.533      0.126    -9.6e+06    1.19e+06
# np.power(weight_norm, 2)   2.071e+07   1.38e+07      1.500      0.134   -6.43e+06    4.79e+07
# np.power(weight_norm, 3)  -6.017e+07   4.11e+07     -1.465      0.144   -1.41e+08    2.06e+07
# np.power(weight_norm, 4)   1.146e+08   8.02e+07      1.429      0.154   -4.31e+07    2.72e+08
# np.power(weight_norm, 5)  -1.505e+08   1.08e+08     -1.392      0.165   -3.63e+08    6.21e+07
# np.power(weight_norm, 6)   1.389e+08   1.03e+08      1.355      0.176   -6.27e+07    3.41e+08
# np.power(weight_norm, 7)  -9.031e+07   6.85e+07     -1.318      0.188   -2.25e+08    4.44e+07
# np.power(weight_norm, 8)   4.052e+07   3.16e+07      1.282      0.201   -2.16e+07    1.03e+08
# np.power(weight_norm, 9)  -1.196e+07    9.6e+06     -1.246      0.214   -3.08e+07    6.91e+06
# np.power(weight_norm, 10)   2.09e+06   1.73e+06      1.211      0.227    -1.3e+06    5.48e+06
# np.power(weight_norm, 11)  -1.64e+05   1.39e+05     -1.178      0.240   -4.38e+05     1.1e+05
# ==============================================================================
# Omnibus:                       54.966   Durbin-Watson:                   0.770
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               96.904
# Skew:                           0.820   Prob(JB):                     9.07e-22
# Kurtosis:                       4.800   Cond. No.                     5.59e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.82e-16. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 12 0.7209 0.7121
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6) + np.power(weight_norm, 7) + np.power(weight_norm, 8) + np.power(weight_norm, 9) + np.power(weight_norm, 10) + np.power(weight_norm, 11) + np.power(weight_norm, 12)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     81.59
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           3.98e-97
# Time:                        03:40:25   Log-Likelihood:                -1111.0
# No. Observations:                 392   AIC:                             2248.
# Df Residuals:                     379   BIC:                             2300.
# Df Model:                          12
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                   2.42e+05   9.39e+05      0.258      0.797    -1.6e+06    2.09e+06
# weight_norm               -2.479e+06   1.15e+07     -0.215      0.830   -2.52e+07    2.02e+07
# np.power(weight_norm, 2)   1.106e+07   6.42e+07      0.172      0.863   -1.15e+08    1.37e+08
# np.power(weight_norm, 3)  -2.793e+07   2.13e+08     -0.131      0.896   -4.47e+08    3.91e+08
# np.power(weight_norm, 4)     4.3e+07   4.72e+08      0.091      0.927   -8.85e+08    9.71e+08
# np.power(weight_norm, 5)  -3.887e+07   7.33e+08     -0.053      0.958   -1.48e+09     1.4e+09
# np.power(weight_norm, 6)    1.39e+07   8.18e+08      0.017      0.986    -1.6e+09    1.62e+09
# np.power(weight_norm, 7)   1.124e+07   6.63e+08      0.017      0.986   -1.29e+09    1.31e+09
# np.power(weight_norm, 8)  -1.883e+07   3.87e+08     -0.049      0.961   -7.79e+08    7.41e+08
# np.power(weight_norm, 9)   1.239e+07   1.58e+08      0.078      0.938   -2.99e+08    3.24e+08
# np.power(weight_norm, 10) -4.569e+06   4.33e+07     -0.106      0.916   -8.97e+07    8.05e+07
# np.power(weight_norm, 11)  9.263e+05   7.08e+06      0.131      0.896    -1.3e+07    1.48e+07
# np.power(weight_norm, 12) -8.087e+04   5.25e+05     -0.154      0.878   -1.11e+06    9.52e+05
# ==============================================================================
# Omnibus:                       54.731   Durbin-Watson:                   0.769
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               96.282
# Skew:                           0.818   Prob(JB):                     1.24e-21
# Kurtosis:                       4.794   Cond. No.                     6.82e+11
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.38e-18. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 13 0.7228 0.7133
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6) + np.power(weight_norm, 7) + np.power(weight_norm, 8) + np.power(weight_norm, 9) + np.power(weight_norm, 10) + np.power(weight_norm, 11) + np.power(weight_norm, 12) + np.power(weight_norm, 13)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.723
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     75.82
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           1.05e-96
# Time:                        03:40:25   Log-Likelihood:                -1109.7
# No. Observations:                 392   AIC:                             2247.
# Df Residuals:                     378   BIC:                             2303.
# Df Model:                          13
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                 -5.435e+06   3.68e+06     -1.476      0.141   -1.27e+07     1.8e+06
# weight_norm                7.361e+07   4.91e+07      1.499      0.135   -2.29e+07     1.7e+08
# np.power(weight_norm, 2)  -4.534e+08   2.98e+08     -1.520      0.129   -1.04e+09    1.33e+08
# np.power(weight_norm, 3)   1.682e+09   1.09e+09      1.538      0.125   -4.68e+08    3.83e+09
# np.power(weight_norm, 4)  -4.195e+09    2.7e+09     -1.554      0.121    -9.5e+09    1.11e+09
# np.power(weight_norm, 5)   7.426e+09   4.74e+09      1.567      0.118   -1.89e+09    1.67e+10
# np.power(weight_norm, 6)  -9.603e+09   6.09e+09     -1.578      0.115   -2.16e+10    2.37e+09
# np.power(weight_norm, 7)   9.189e+09   5.79e+09      1.586      0.114    -2.2e+09    2.06e+10
# np.power(weight_norm, 8)  -6.508e+09   4.09e+09     -1.592      0.112   -1.45e+10    1.53e+09
# np.power(weight_norm, 9)   3.371e+09   2.11e+09      1.596      0.111   -7.83e+08    7.52e+09
# np.power(weight_norm, 10) -1.242e+09   7.77e+08     -1.598      0.111   -2.77e+09    2.86e+08
# np.power(weight_norm, 11)  3.081e+08   1.93e+08      1.598      0.111    -7.1e+07    6.87e+08
# np.power(weight_norm, 12) -4.617e+07   2.89e+07     -1.597      0.111   -1.03e+08    1.07e+07
# np.power(weight_norm, 13)  3.158e+06   1.98e+06      1.594      0.112   -7.37e+05    7.05e+06
# ==============================================================================
# Omnibus:                       58.398   Durbin-Watson:                   0.779
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              106.890
# Skew:                           0.850   Prob(JB):                     6.15e-24
# Kurtosis:                       4.912   Cond. No.                     8.51e+12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.42e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 14 0.7240 0.7138
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6) + np.power(weight_norm, 7) + np.power(weight_norm, 8) + np.power(weight_norm, 9) + np.power(weight_norm, 10) + np.power(weight_norm, 11) + np.power(weight_norm, 12) + np.power(weight_norm, 13) + np.power(weight_norm, 14)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.724
# Model:                            OLS   Adj. R-squared:                  0.714
# Method:                 Least Squares   F-statistic:                     70.64
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           4.13e-96
# Time:                        03:40:25   Log-Likelihood:                -1108.9
# No. Observations:                 392   AIC:                             2248.
# Df Residuals:                     377   BIC:                             2307.
# Df Model:                          14
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                 -2.126e+07   1.28e+07     -1.656      0.099   -4.65e+07    3.98e+06
# weight_norm                 3.02e+08   1.84e+08      1.640      0.102   -6.01e+07    6.64e+08
# np.power(weight_norm, 2)  -1.965e+09   1.21e+09     -1.621      0.106   -4.35e+09    4.18e+08
# np.power(weight_norm, 3)   7.764e+09   4.85e+09      1.601      0.110   -1.77e+09    1.73e+10
# np.power(weight_norm, 4)  -2.082e+10   1.32e+10     -1.577      0.116   -4.68e+10    5.13e+09
# np.power(weight_norm, 5)   4.009e+10   2.58e+10      1.553      0.121   -1.07e+10    9.09e+10
# np.power(weight_norm, 6)  -5.718e+10   3.75e+10     -1.526      0.128   -1.31e+11    1.65e+10
# np.power(weight_norm, 7)   6.139e+10    4.1e+10      1.498      0.135   -1.92e+10    1.42e+11
# np.power(weight_norm, 8)  -4.986e+10   3.39e+10     -1.469      0.143   -1.17e+11    1.69e+10
# np.power(weight_norm, 9)    3.05e+10   2.12e+10      1.439      0.151   -1.12e+10    7.22e+10
# np.power(weight_norm, 10) -1.384e+10   9.82e+09     -1.409      0.160   -3.32e+10    5.47e+09
# np.power(weight_norm, 11)  4.518e+09   3.28e+09      1.379      0.169   -1.93e+09     1.1e+10
# np.power(weight_norm, 12) -1.003e+09   7.44e+08     -1.348      0.179   -2.47e+09     4.6e+08
# np.power(weight_norm, 13)  1.357e+08   1.03e+08      1.317      0.189   -6.69e+07    3.38e+08
# np.power(weight_norm, 14) -8.442e+06   6.56e+06     -1.287      0.199   -2.13e+07    4.46e+06
# ==============================================================================
# Omnibus:                       60.954   Durbin-Watson:                   0.781
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              115.011
# Skew:                           0.870   Prob(JB):                     1.06e-25
# Kurtosis:                       5.003   Cond. No.                     9.40e+13
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.08e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 15 0.7238 0.7136
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6) + np.power(weight_norm, 7) + np.power(weight_norm, 8) + np.power(weight_norm, 9) + np.power(weight_norm, 10) + np.power(weight_norm, 11) + np.power(weight_norm, 12) + np.power(weight_norm, 13) + np.power(weight_norm, 14) + np.power(weight_norm, 15)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.724
# Model:                            OLS   Adj. R-squared:                  0.714
# Method:                 Least Squares   F-statistic:                     70.58
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           4.65e-96
# Time:                        03:40:25   Log-Likelihood:                -1109.0
# No. Observations:                 392   AIC:                             2248.
# Df Residuals:                     377   BIC:                             2308.
# Df Model:                          14
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                  -1.13e+07   6.67e+06     -1.694      0.091   -2.44e+07    1.82e+06
# weight_norm                1.493e+08   8.85e+07      1.687      0.092   -2.47e+07    3.23e+08
# np.power(weight_norm, 2)  -8.847e+08   5.27e+08     -1.678      0.094   -1.92e+09    1.52e+08
# np.power(weight_norm, 3)   3.088e+09   1.85e+09      1.665      0.097   -5.59e+08    6.74e+09
# np.power(weight_norm, 4)  -6.963e+09   4.22e+09     -1.648      0.100   -1.53e+10    1.34e+09
# np.power(weight_norm, 5)   1.031e+10   6.33e+09      1.627      0.105   -2.15e+09    2.28e+10
# np.power(weight_norm, 6)  -9.218e+09   5.78e+09     -1.596      0.111   -2.06e+10    2.14e+09
# np.power(weight_norm, 7)   2.442e+09   1.67e+09      1.466      0.144   -8.34e+08    5.72e+09
# np.power(weight_norm, 8)   5.885e+09   3.59e+09      1.639      0.102   -1.18e+09    1.29e+10
# np.power(weight_norm, 9)  -1.008e+10   6.36e+09     -1.585      0.114   -2.26e+10    2.42e+09
# np.power(weight_norm, 10)  8.715e+09   5.61e+09      1.553      0.121   -2.32e+09    1.98e+10
# np.power(weight_norm, 11) -4.885e+09   3.21e+09     -1.524      0.128   -1.12e+10    1.42e+09
# np.power(weight_norm, 12)  1.843e+09   1.23e+09      1.496      0.135   -5.79e+08    4.27e+09
# np.power(weight_norm, 13) -4.552e+08    3.1e+08     -1.469      0.143   -1.06e+09    1.54e+08
# np.power(weight_norm, 14)  6.679e+07   4.63e+07      1.441      0.150   -2.43e+07    1.58e+08
# np.power(weight_norm, 15) -4.429e+06   3.13e+06     -1.414      0.158   -1.06e+07    1.73e+06
# ==============================================================================
# Omnibus:                       60.938   Durbin-Watson:                   0.780
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              114.837
# Skew:                           0.871   Prob(JB):                     1.16e-25
# Kurtosis:                       5.000   Cond. No.                     1.04e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.82e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 16 0.7243 0.7140
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6) + np.power(weight_norm, 7) + np.power(weight_norm, 8) + np.power(weight_norm, 9) + np.power(weight_norm, 10) + np.power(weight_norm, 11) + np.power(weight_norm, 12) + np.power(weight_norm, 13) + np.power(weight_norm, 14) + np.power(weight_norm, 15) + np.power(weight_norm, 16)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.724
# Model:                            OLS   Adj. R-squared:                  0.714
# Method:                 Least Squares   F-statistic:                     70.74
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           3.42e-96
# Time:                        03:40:25   Log-Likelihood:                -1108.7
# No. Observations:                 392   AIC:                             2247.
# Df Residuals:                     377   BIC:                             2307.
# Df Model:                          14
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                 -2.905e+07   2.33e+07     -1.246      0.214   -7.49e+07    1.68e+07
# weight_norm                4.047e+08   3.33e+08      1.215      0.225    -2.5e+08    1.06e+09
# np.power(weight_norm, 2)  -2.553e+09   2.16e+09     -1.182      0.238    -6.8e+09    1.69e+09
# np.power(weight_norm, 3)   9.594e+09   8.35e+09      1.148      0.252   -6.83e+09     2.6e+10
# np.power(weight_norm, 4)  -2.371e+10   2.13e+10     -1.113      0.267   -6.56e+10    1.82e+10
# np.power(weight_norm, 5)   3.968e+10   3.69e+10      1.074      0.284    -3.3e+10    1.12e+11
# np.power(weight_norm, 6)  -4.343e+10   4.22e+10     -1.029      0.304   -1.26e+11    3.96e+10
# np.power(weight_norm, 7)   2.443e+10   2.57e+10      0.951      0.342   -2.61e+10    7.49e+10
# np.power(weight_norm, 8)   9.236e+09    7.2e+09      1.284      0.200   -4.91e+09    2.34e+10
# np.power(weight_norm, 9)  -3.548e+10   3.48e+10     -1.020      0.309   -1.04e+11    3.29e+10
# np.power(weight_norm, 10)  4.009e+10   4.15e+10      0.966      0.335   -4.15e+10    1.22e+11
# np.power(weight_norm, 11) -2.815e+10   3.04e+10     -0.927      0.355   -8.79e+10    3.16e+10
# np.power(weight_norm, 12)  1.356e+10   1.52e+10      0.893      0.372   -1.63e+10    4.34e+10
# np.power(weight_norm, 13) -4.514e+09   5.23e+09     -0.862      0.389   -1.48e+10    5.78e+09
# np.power(weight_norm, 14)      1e+09    1.2e+09      0.833      0.405   -1.36e+09    3.36e+09
# np.power(weight_norm, 15) -1.333e+08   1.65e+08     -0.806      0.421   -4.58e+08    1.92e+08
# np.power(weight_norm, 16)  8.097e+06   1.04e+07      0.781      0.436   -1.23e+07    2.85e+07
# ==============================================================================
# Omnibus:                       60.710   Durbin-Watson:                   0.783
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              114.552
# Skew:                           0.867   Prob(JB):                     1.33e-25
# Kurtosis:                       5.001   Cond. No.                     1.18e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.43e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 17 0.7244 0.7134
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6) + np.power(weight_norm, 7) + np.power(weight_norm, 8) + np.power(weight_norm, 9) + np.power(weight_norm, 10) + np.power(weight_norm, 11) + np.power(weight_norm, 12) + np.power(weight_norm, 13) + np.power(weight_norm, 14) + np.power(weight_norm, 15) + np.power(weight_norm, 16) + np.power(weight_norm, 17)
# ...
# Time:                        03:40:25   Log-Likelihood:                -1108.6
# No. Observations:                 392   AIC:                             2249.
# Df Residuals:                     376   BIC:                             2313.
# Df Model:                          15
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                 -1.907e+07   1.27e+07     -1.502      0.134    -4.4e+07    5.89e+06
# weight_norm                2.498e+08   1.69e+08      1.476      0.141   -8.29e+07    5.82e+08
# np.power(weight_norm, 2)  -1.456e+09   1.01e+09     -1.448      0.148   -3.43e+09    5.21e+08
# np.power(weight_norm, 3)   4.921e+09   3.47e+09      1.417      0.157   -1.91e+09    1.17e+10
# np.power(weight_norm, 4)  -1.046e+10   7.57e+09     -1.382      0.168   -2.53e+10    4.42e+09
# np.power(weight_norm, 5)   1.375e+10   1.03e+10      1.340      0.181   -6.43e+09    3.39e+10
# np.power(weight_norm, 6)  -8.938e+09   7.06e+09     -1.265      0.207   -2.28e+10    4.95e+09
# np.power(weight_norm, 7)  -2.838e+09   1.78e+09     -1.594      0.112   -6.34e+09    6.62e+08
# np.power(weight_norm, 8)   1.108e+10   8.45e+09      1.311      0.191   -5.53e+09    2.77e+10
# np.power(weight_norm, 9)  -7.403e+09   6.13e+09     -1.208      0.228   -1.94e+10    4.64e+09
# np.power(weight_norm, 10) -3.867e+09   2.66e+09     -1.455      0.147   -9.09e+09    1.36e+09
# np.power(weight_norm, 11)  1.166e+10   9.19e+09      1.269      0.205    -6.4e+09    2.97e+10
# np.power(weight_norm, 12) -1.126e+10   9.24e+09     -1.218      0.224   -2.94e+10    6.92e+09
# np.power(weight_norm, 13)  6.511e+09   5.52e+09      1.180      0.239   -4.34e+09    1.74e+10
# np.power(weight_norm, 14) -2.457e+09   2.14e+09     -1.147      0.252   -6.67e+09    1.75e+09
# np.power(weight_norm, 15)  5.977e+08   5.35e+08      1.117      0.265   -4.54e+08    1.65e+09
# np.power(weight_norm, 16) -8.564e+07   7.86e+07     -1.089      0.277    -2.4e+08     6.9e+07
# np.power(weight_norm, 17)  5.519e+06   5.19e+06      1.062      0.289    -4.7e+06    1.57e+07
# ==============================================================================
# Omnibus:                       61.056   Durbin-Watson:                   0.784
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              115.688
# Skew:                           0.870   Prob(JB):                     7.56e-26
# Kurtosis:                       5.014   Cond. No.                     1.27e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.4e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 18 0.7244 0.7134
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6) + np.power(weight_norm, 7) + np.power(weight_norm, 8) + np.power(weight_norm, 9) + np.power(weight_norm, 10) + np.power(weight_norm, 11) + np.power(weight_norm, 12) + np.power(weight_norm, 13) + np.power(weight_norm, 14) + np.power(weight_norm, 15) + np.power(weight_norm, 16) + np.power(weight_norm, 17) + np.power(weight_norm, 18)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.724
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     65.89
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           2.68e-95
# Time:                        03:40:25   Log-Likelihood:                -1108.6
# No. Observations:                 392   AIC:                             2249.
# Df Residuals:                     376   BIC:                             2313.
# Df Model:                          15
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                 -1.186e+07   7.08e+06     -1.675      0.095   -2.58e+07    2.06e+06
# weight_norm                1.462e+08   8.83e+07      1.657      0.098   -2.73e+07     3.2e+08
# np.power(weight_norm, 2)  -7.881e+08   4.82e+08     -1.635      0.103   -1.74e+09     1.6e+08
# np.power(weight_norm, 3)   2.396e+09   1.49e+09      1.609      0.109   -5.32e+08    5.32e+09
# np.power(weight_norm, 4)  -4.345e+09   2.76e+09     -1.577      0.116   -9.76e+09    1.07e+09
# np.power(weight_norm, 5)   4.266e+09   2.79e+09      1.529      0.127   -1.22e+09    9.75e+09
# np.power(weight_norm, 6)  -7.034e+08   5.72e+08     -1.230      0.219   -1.83e+09    4.21e+08
# np.power(weight_norm, 7)  -3.302e+09   2.11e+09     -1.565      0.119   -7.45e+09    8.48e+08
# np.power(weight_norm, 8)   2.897e+09   1.99e+09      1.457      0.146   -1.01e+09    6.81e+09
# np.power(weight_norm, 9)   1.386e+09   8.27e+08      1.677      0.094   -2.39e+08    3.01e+09
# np.power(weight_norm, 10) -3.685e+09   2.48e+09     -1.483      0.139   -8.57e+09     1.2e+09
# np.power(weight_norm, 11)  1.113e+09   8.68e+08      1.283      0.200   -5.93e+08    2.82e+09
# np.power(weight_norm, 12)  2.867e+09   1.89e+09      1.518      0.130   -8.47e+08    6.58e+09
# np.power(weight_norm, 13) -4.212e+09   2.92e+09     -1.443      0.150   -9.95e+09    1.53e+09
# np.power(weight_norm, 14)  2.942e+09    2.1e+09      1.402      0.162   -1.18e+09    7.07e+09
# np.power(weight_norm, 15)  -1.25e+09   9.13e+08     -1.369      0.172   -3.05e+09    5.45e+08
# np.power(weight_norm, 16)  3.311e+08   2.47e+08      1.339      0.181   -1.55e+08    8.17e+08
# np.power(weight_norm, 17) -5.063e+07   3.86e+07     -1.312      0.190   -1.27e+08    2.53e+07
# np.power(weight_norm, 18)  3.436e+06   2.67e+06      1.286      0.199   -1.82e+06    8.69e+06
# ==============================================================================
# Omnibus:                       61.419   Durbin-Watson:                   0.784
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              116.812
# Skew:                           0.873   Prob(JB):                     4.31e-26
# Kurtosis:                       5.025   Cond. No.                     3.99e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.46e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 19 0.7244 0.7134
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6) + np.power(weight_norm, 7) + np.power(weight_norm, 8) + np.power(weight_norm, 9) + np.power(weight_norm, 10) + np.power(weight_norm, 11) + np.power(weight_norm, 12) + np.power(weight_norm, 13) + np.power(weight_norm, 14) + np.power(weight_norm, 15) + np.power(weight_norm, 16) + np.power(weight_norm, 17) + np.power(weight_norm, 18) + np.power(weight_norm, 19)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.724
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     65.90
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           2.66e-95
# Time:                        03:40:25   Log-Likelihood:                -1108.6
# No. Observations:                 392   AIC:                             2249.
# Df Residuals:                     376   BIC:                             2313.
# Df Model:                          15
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                 -1.617e+07    2.5e+07     -0.647      0.518   -6.54e+07     3.3e+07
# weight_norm                2.057e+08   3.38e+08      0.608      0.543   -4.59e+08     8.7e+08
# np.power(weight_norm, 2)  -1.152e+09   2.03e+09     -0.569      0.570   -5.14e+09    2.83e+09
# np.power(weight_norm, 3)   3.691e+09      7e+09      0.527      0.598   -1.01e+10    1.75e+10
# np.power(weight_norm, 4)  -7.236e+09    1.5e+10     -0.482      0.630   -3.67e+10    2.23e+10
# np.power(weight_norm, 5)   8.257e+09   1.93e+10      0.427      0.670   -2.98e+10    4.63e+10
# np.power(weight_norm, 6)  -3.464e+09   1.09e+10     -0.317      0.751    -2.5e+10     1.8e+10
# np.power(weight_norm, 7)  -3.974e+09   7.12e+09     -0.558      0.577    -1.8e+10       1e+10
# np.power(weight_norm, 8)   5.969e+09    1.6e+10      0.374      0.709   -2.54e+10    3.74e+10
# np.power(weight_norm, 9)  -3.624e+08   4.51e+09     -0.080      0.936   -9.24e+09    8.51e+09
# np.power(weight_norm, 10) -5.206e+09   1.27e+10     -0.409      0.683   -3.02e+10    1.98e+10
# np.power(weight_norm, 11)  3.851e+09   1.34e+10      0.287      0.774   -2.25e+10    3.02e+10
# np.power(weight_norm, 12)   1.92e+09   2.55e+09      0.753      0.452   -3.09e+09    6.93e+09
# np.power(weight_norm, 13) -5.537e+09   1.64e+10     -0.337      0.736   -3.78e+10    2.67e+10
# np.power(weight_norm, 14)  4.935e+09   1.75e+10      0.282      0.778   -2.95e+10    3.94e+10
# np.power(weight_norm, 15) -2.592e+09   1.06e+10     -0.245      0.806   -2.34e+10    1.82e+10
# np.power(weight_norm, 16)  8.779e+08   4.07e+09      0.216      0.829   -7.13e+09    8.88e+09
# np.power(weight_norm, 17) -1.897e+08      1e+09     -0.190      0.850   -2.16e+09    1.78e+09
# np.power(weight_norm, 18)  2.391e+07   1.44e+08      0.166      0.868   -2.59e+08    3.07e+08
# np.power(weight_norm, 19) -1.342e+06   9.26e+06     -0.145      0.885   -1.96e+07    1.69e+07
# ==============================================================================
# Omnibus:                       61.028   Durbin-Watson:                   0.784
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              115.714
# Skew:                           0.869   Prob(JB):                     7.46e-26
# Kurtosis:                       5.015   Cond. No.                     1.03e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.92e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# 20 0.7245 0.7135
# mpg ~ weight_norm + np.power(weight_norm, 2) + np.power(weight_norm, 3) + np.power(weight_norm, 4) + np.power(weight_norm, 5) + np.power(weight_norm, 6) + np.power(weight_norm, 7) + np.power(weight_norm, 8) + np.power(weight_norm, 9) + np.power(weight_norm, 10) + np.power(weight_norm, 11) + np.power(weight_norm, 12) + np.power(weight_norm, 13) + np.power(weight_norm, 14) + np.power(weight_norm, 15) + np.power(weight_norm, 16) + np.power(weight_norm, 17) + np.power(weight_norm, 18) + np.power(weight_norm, 19) + np.power(weight_norm, 20)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.725
# Model:                            OLS   Adj. R-squared:                  0.714
# Method:                 Least Squares   F-statistic:                     65.93
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           2.49e-95
# Time:                        03:40:25   Log-Likelihood:                -1108.5
# No. Observations:                 392   AIC:                             2249.
# Df Residuals:                     376   BIC:                             2313.
# Df Model:                          15
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                 -1.446e+07   1.43e+07     -1.010      0.313   -4.26e+07    1.37e+07
# weight_norm                1.774e+08   1.82e+08      0.974      0.331   -1.81e+08    5.36e+08
# np.power(weight_norm, 2)  -9.467e+08   1.01e+09     -0.935      0.350   -2.94e+09    1.04e+09
# np.power(weight_norm, 3)   2.827e+09   3.17e+09      0.893      0.373    -3.4e+09    9.05e+09
# np.power(weight_norm, 4)  -4.954e+09   5.87e+09     -0.844      0.399   -1.65e+10    6.59e+09
# np.power(weight_norm, 5)   4.486e+09    5.8e+09      0.773      0.440   -6.93e+09    1.59e+10
# np.power(weight_norm, 6)  -1.415e+08   8.17e+08     -0.173      0.862   -1.75e+09    1.46e+09
# np.power(weight_norm, 7)  -3.838e+09   4.72e+09     -0.813      0.417   -1.31e+10    5.44e+09
# np.power(weight_norm, 8)    2.22e+09   3.45e+09      0.644      0.520   -4.56e+09       9e+09
# np.power(weight_norm, 9)   2.539e+09   2.91e+09      0.871      0.384   -3.19e+09    8.27e+09
# np.power(weight_norm, 10) -3.105e+09   4.57e+09     -0.679      0.498   -1.21e+10    5.89e+09
# np.power(weight_norm, 11) -1.155e+09   1.02e+09     -1.133      0.258   -3.16e+09    8.49e+08
# np.power(weight_norm, 12)  3.558e+09    5.1e+09      0.698      0.486   -6.46e+09    1.36e+10
# np.power(weight_norm, 13) -9.028e+08   1.92e+09     -0.470      0.639   -4.68e+09    2.88e+09
# np.power(weight_norm, 14) -2.926e+09   3.97e+09     -0.738      0.461   -1.07e+10    4.87e+09
# np.power(weight_norm, 15)   3.96e+09   6.11e+09      0.648      0.517   -8.05e+09     1.6e+10
# np.power(weight_norm, 16) -2.599e+09   4.31e+09     -0.603      0.547   -1.11e+10    5.87e+09
# np.power(weight_norm, 17)   1.04e+09   1.83e+09      0.569      0.570   -2.55e+09    4.63e+09
# np.power(weight_norm, 18) -2.595e+08   4.81e+08     -0.540      0.590    -1.2e+09    6.86e+08
# np.power(weight_norm, 19)  3.738e+07   7.28e+07      0.513      0.608   -1.06e+08    1.81e+08
# np.power(weight_norm, 20)  -2.39e+06   4.89e+06     -0.489      0.625    -1.2e+07    7.23e+06
# ==============================================================================
# Omnibus:                       61.040   Durbin-Watson:                   0.783
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              115.778
# Skew:                           0.869   Prob(JB):                     7.23e-26
# Kurtosis:                       5.016   Cond. No.                     2.05e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.77e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# tests best_degree, best_r_squared, and sound_degree

# %% [markdown]
# ### TODO:
# Open the Peer Review assignment for this week to answer a question for section 1d.

# %% [markdown]
# # 2. Multi-Linear Regression [15 pts, Peer Review]

# %% [markdown]
# In the following problem, you will construct a simple multi-linear regression model, identify interaction terms and use diagnostic plots to identify outliers in the data. The original problem is as described by John Verzani in the [excellent tutorial 'SimplR' on the R statistics language](https://cran.r-project.org/doc/contrib/Verzani-SimpleR.pdf) and uses data from the 2000 presidential election in Florida. The problem is interesting because it contains a small number of highly leveraged points that influence the model.

# %%
votes = pd.read_csv('data/fl2000.txt', delim_whitespace=True, comment='#')
votes = votes[['county', 'Bush', 'Gore', 'Nader', 'Buchanan']]
votes.describe(include='all')
# Out:
#          county           Bush           Gore         Nader     Buchanan
# count        67      67.000000      67.000000     67.000000    67.000000
# unique       67            NaN            NaN           NaN          NaN
# top     Alachua            NaN            NaN           NaN          NaN
# freq          1            NaN            NaN           NaN          NaN
# mean        NaN   43450.970149   43453.985075   1454.119403   260.880597
# std         NaN   57182.620266   75070.435056   2033.620972   450.498092
# min         NaN    1317.000000     789.000000     19.000000     9.000000
# 25%         NaN    4757.000000    3058.000000     95.500000    46.500000
# 50%         NaN   20206.000000   14167.000000    562.000000   120.000000
# 75%         NaN   56546.500000   46015.000000   1870.500000   285.500000
# max         NaN  289533.000000  387703.000000  10022.000000  3411.000000

# %% [markdown]
# ### 2a. Plot a pair plot of the data using the `seaborn` library. [Peer Review]
# Upload a screenshot or saved copy of your plot for this week's Peer Review assignment.<br>
# **Note:** your code for this section may cause the Validate button to time out. If you want to run the Validate button prior to submitting, you could comment out the code in this section after completing the Peer Review.

# %%
# plot a pair plot of the data using the seaborn library
# possible way to save the image
# plt.savefig('pair_plot.png', dpi = 300, bbox_inches = 'tight')
# your code here
from scipy.stats import pearsonr
import matplotlib.pyplot as plt 

def corrfunc(x, y, ax=None, **kws):
    """Plot the correlation coefficient in the top left hand corner of a plot."""
    r, _ = pearsonr(x, y)
    ax = ax or plt.gca()
    ax.annotate(f'ρ = {r:.2f}', xy=(.1, .9), xycoords=ax.transAxes)
    
plt.figure(figsize=(12,14))
plt.subplots_adjust(0,0,1,0.925,0.05,0.05)
sns.set(font_scale=1.2)
g = sns.pairplot(votes, diag_kind='kde')
g.map_lower(corrfunc)
plt.suptitle('Pair Plot', size=15)
plt.show()

# %% [markdown]
# ### 2b. Comment on the relationship between the quantiative datasets. Are they correlated? Collinear? [Peer Review]
# You will answer this question in this week's Peer Review assignment.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X = votes[['Gore', 'Nader', 'Buchanan']].values
for i in range(3):
    print(variance_inflation_factor(X, i))
# Out:
# 5.881763338498265
# 5.537711423677805
# 2.573888958823117

# %% [markdown]
# ### 2c. Multi-linear [5 pts, Peer Review]
#
# Construct a multi-linear model called `model` without interaction terms predicting the Bush column on the other columns and print out the summary table. You should name your model's object as `model` in order to pass the autograder. Use the full data (not train-test split for now) and do not scale features.

# %%
# uncomment and construct a multi-linear model 
# model = 
# your code here
votes = votes.dropna()
votes['county'] = votes['county'].astype('str')
#model = smf.ols(formula='Bush~C(county)+Gore+Nader+Buchanan', data=votes)
#model = smf.ols(formula='Bush~Gore+Nader+Buchanan+1', data=votes).fit()
model = smf.ols(formula='Bush~Gore+Nader+Buchanan', data=votes).fit()
#y, X = votes['Bush'].values, votes[['Gore', 'Nader', 'Buchanan']].values
#X = sm.add_constant(X) 
#model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Bush   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.871
# Method:                 Least Squares   F-statistic:                     149.5
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           1.35e-28
# Time:                        04:20:00   Log-Likelihood:                -758.33
# No. Observations:                  67   AIC:                             1525.
# Df Residuals:                      63   BIC:                             1533.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8647.6837   3133.545      2.760      0.008    2385.793    1.49e+04
# Gore           0.4475      0.071      6.305      0.000       0.306       0.589
# Nader         11.8533      2.503      4.735      0.000       6.851      16.855
# Buchanan      -7.2033      7.864     -0.916      0.363     -22.917       8.511
# ==============================================================================
# Omnibus:                       20.698   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              128.017
# Skew:                           0.383   Prob(JB):                     1.59e-28
# Kurtosis:                       9.728   Cond. No.                     1.08e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# tests model

# %% [markdown]
# Is there any insignificant feature(s)? Explain your answer in this week's Peer Review assignment.

# %% [markdown]
# ### 2d. Multi-linear with interactions [Peer Review]
#
# Construct a multi-linear model with interactions that are statistically significant at the $p = 0.05$ level. You can start with full interactions and then eliminate interactions that do not meet the $p = 0.05$ threshold. You will share your solution in this week's Peer Review assignment.
#
# Note: Name this model object as **`model_multi`**.

# %%
# uncomment and construct multi-linear model 
# model_multi = 
# your code here
model_multi = smf.ols(formula='Bush~Gore+Nader+Gore:Nader+Gore:Buchanan+Nader:Buchanan+1', data=votes).fit()
print(model_multi.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Bush   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.944
# Method:                 Least Squares   F-statistic:                     223.3
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           7.63e-38
# Time:                        04:20:05   Log-Likelihood:                -729.31
# No. Observations:                  67   AIC:                             1471.
# Df Residuals:                      61   BIC:                             1484.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        592.5059   2384.941      0.248      0.805   -4176.477    5361.489
# Gore               1.7895      0.179      9.978      0.000       1.431       2.148
# Nader            -11.4015      5.022     -2.270      0.027     -21.443      -1.360
# Gore:Nader        -0.0001   1.55e-05     -8.451      0.000      -0.000      -0.000
# Gore:Buchanan     -0.0008      0.000     -5.814      0.000      -0.001      -0.001
# Nader:Buchanan     0.0371      0.007      5.399      0.000       0.023       0.051
# ==============================================================================
# Omnibus:                        6.010   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.050   Jarque-Bera (JB):                9.326
# Skew:                          -0.083   Prob(JB):                      0.00944
# Kurtosis:                       4.820   Cond. No.                     7.91e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.91e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
model_multi = smf.ols(formula='Bush~Gore+Nader+Gore:Nader', data=votes).fit()
print(model_multi.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Bush   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.910
# Method:                 Least Squares   F-statistic:                     222.3
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           1.88e-33
# Time:                        04:31:53   Log-Likelihood:                -746.42
# No. Observations:                  67   AIC:                             1501.
# Df Residuals:                      63   BIC:                             1510.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    131.8901   3010.301      0.044      0.965   -5883.717    6147.497
# Gore           0.8398      0.096      8.737      0.000       0.648       1.032
# Nader         14.7989      2.162      6.846      0.000      10.479      19.119
# Gore:Nader -7.605e-05   1.43e-05     -5.300      0.000      -0.000   -4.74e-05
# ==============================================================================
# Omnibus:                       16.584   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.885
# Skew:                           0.517   Prob(JB):                     1.99e-12
# Kurtosis:                       7.270   Cond. No.                     7.75e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.75e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# tests model_multi

# %%
# tests model_multi 
# your code here

# %% [markdown]
# ### 2e. Leverage [Peer Review]
#
# Plot the *leverage* vs. the square of the residual.
#
# These resources might be helpful
# - https://rpubs.com/Amrabdelhamed611/669768
# - https://www.statsmodels.org/dev/generated/statsmodels.graphics.regressionplots.plot_leverage_resid2.html

# %%
# plot the leverage vs. the square of the residual
# your code here
sm.graphics.plot_leverage_resid2(model_multi)
plt.show()

# %%
# you can use this cell to try different plots 
# your code here

# %% [markdown]
# Upload your plot for this week's Peer Review assignment. If you tried out multiple models, upload a single model.

# %% [markdown]
# ### 2f. Identify and Clean [5pts]
#
# The leverage *vs* residual plot indicates that some rows have high leverage but small residuals and others have high residual. The $R^2$ of the model is determined by the residual. The data is from the disputed 2000 election [where one county](https://en.wikipedia.org/wiki/2000_United_States_presidential_election_recount_in_Florida) caused significant issues.
#
# Display the *3 or more* rows for the points indicated having high leverage and/or high residual squared. You will use this to improve the model $R^2$.
#
# Name the list of indices for those high-leverage and/or high-residual points as `unusual`.

# %%
# uncomment and fill unusual with list of indices for high-leverage and/or high-residual points
# unusual = []
# your code here
unusual = [0, 5, 27, 34, 35, 42, 45, 49, 51, 55, 63]
votes.loc[unusual]
# Out:
#           county    Bush    Gore  Nader  Buchanan
# 0        Alachua   34124   47365   3226       263
# 5        Broward  177902  387703   7104       795
# 27  Hillsborough  180760  169557   7490       847
# 34           Lee  106141   73560   3587       305
# 35          Leon   39062   61427   1932       282
# 42     MiamiDade  289533  328808   5352       560
# 45      Okaloosa   52093   16948    985       267
# 49     PalmBeach  152951  269732   5565      3411
# 51      Pinellas  184825  200630  10022      1013
# 55      Sarasota   83100   72853   4069       305
# 63       Volusia   82357   97304   2910       498

# %%
# tests your list of indices for high-leverage and/or high-residual points

# %% [markdown]
# ### 2g. Final model [5 pts]
#
# Develop your final model by dropping *one or more* of the troublesome data points indicated in the leverage *vs* residual plot and insuring any interactions in your model are still significant at $p=0.05$. Your model should have an $R^2$ great than 0.95. Call your model `model_final`.

# %%
# develop your model_final here
# model_final = 
# your code here
votes2 = votes.drop(index=unusual)
model_final = smf.ols(formula='Bush~Nader+Gore:Nader+Gore:Buchanan+Nader:Buchanan+1', data=votes2).fit()
print(model_final.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Bush   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     256.2
# Date:                Sat, 11 Nov 2023   Prob (F-statistic):           4.35e-33
# Time:                        20:14:08   Log-Likelihood:                -578.31
# No. Observations:                  56   AIC:                             1167.
# Df Residuals:                      51   BIC:                             1177.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       2253.4604   1543.792      1.460      0.151    -845.830    5352.751
# Nader             30.3955      3.015     10.081      0.000      24.342      36.449
# Gore:Nader        -0.0001   3.21e-05     -3.336      0.002      -0.000   -4.27e-05
# Gore:Buchanan      0.0027      0.000     10.244      0.000       0.002       0.003
# Nader:Buchanan    -0.0540      0.008     -6.486      0.000      -0.071      -0.037
# ==============================================================================
# Omnibus:                       10.870   Durbin-Watson:                   1.549
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.761
# Skew:                           0.818   Prob(JB):                      0.00279
# Kurtosis:                       4.537   Cond. No.                     1.70e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.7e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# tests model_final

# %% [markdown]
# ## 3. Body Mass Index Model [20 points, Peer Review]

# %% [markdown]
# In this problem, you will first clean a data set and create a model to estimate body fat based on the common BMI measure. Then, you will use the **forward stepwise selection** method to create more accurate predictors for body fat.
#
# The body density dataset in file `bodyfat` includes the following 15 variables listed from left to right:
# * Density : Density determined from underwater weighing
# * Fat : Percent body fat from Siri’s (1956) equation
# * Age : Age (years)
# * Weight : Weight (kg)
# * Height : Height (cm)
# * Neck : Neck circumference (cm)
# * Chest: Chest circumference (cm)
# * Abdomen : Abdomen circumference (cm)
# * Hip : Hip circumference (cm)
# * Thigh : Thigh circumference (cm)
# * Knee : Knee circumference (cm)
# * Ankle : Ankle circumference (cm)
# * Biceps : Biceps (extended) circumference (cm)
# * Forearm : Forearm circumference (cm)
# * Wrist : Wrist circumference (cm)
#
# The `Density` column is the "gold standard" -- it is a measure of body density obtained by dunking people in water and measuring the displacement. The `Fat` column is a prediction using another statistical model. The body mass index (BMI) is [calculated as Kg/m^2](https://en.wikipedia.org/wiki/Body_mass_index) and is used to classify people into different weight categories with a [BMI over 30 being 'obese'](https://www.medicalnewstoday.com/info/obesity). You will find that BMI is a poor predictor of the `Density` information it purports to predict. You will try to find better models using measurements and regression.
#
# Unfortunately for us, the dataset we have has imperial units for weight and height, so we will convert those to metric and then calculate the BMI and plot the KDE of the data.

# %%
fat = pd.read_csv('data/bodyfat.csv')
fat = fat.drop('Unnamed: 0', axis=1)
fat.Weight = fat.Weight * 0.453592 # Convert to Kg
fat.Height = fat.Height * 0.0254 # convert inches to m
fat['BMI'] = fat.Weight / (fat.Height**2)
fat.BMI.plot.kde();

# %% [markdown]
# ### 3a. [5 pts]
# The BMI has at least one outlier since it's unlikely anyone has a BMI of 165, even [Arnold Schwarzenegger](http://www.health.com/health/gallery/0,,20460621,00.html).
#
# Form a new table `cfat` (cleaned fat) that removes any rows with a BMI greater than 40 and calculate the regression model predicting the `Density` from the `BMI`. Display the summary of the regression model. Call your model as `bmi`. You should achieve an $R^2$ of at least 0.53.

# %%
fat.head()
# Out:
#    Density  BodyFat  Age     Weight   Height  Neck  Chest  Abdomen    Hip  \
# 0   1.0708     12.3   23  69.966566  1.72085  36.2   93.1     85.2   94.5
# 1   1.0853      6.1   22  78.584814  1.83515  38.5   93.6     83.0   98.7
# 2   1.0414     25.3   22  69.853168  1.68275  34.0   95.8     87.9   99.2
# 3   1.0751     10.4   26  83.801122  1.83515  37.4  101.8     86.4  101.2
# 4   1.0340     28.7   24  83.574326  1.80975  34.4   97.3    100.0  101.9
#
#    Thigh  Knee  Ankle  Biceps  Forearm  Wrist        BMI
# 0   59.0  37.3   21.9    32.0     27.4   17.1  23.626779
# 1   58.7  37.3   23.4    30.5     28.9   18.2  23.334338
# 2   59.6  38.9   24.0    28.8     25.2   16.6  24.668737
# 3   60.1  37.3   22.8    32.4     29.4   18.2  24.883227
# 4   63.2  42.2   24.0    32.2     27.7   17.7  25.517358

# %%
# form new table cfat and model bmi
# cfat = 
# bmi = 
# your code here
cfat = fat[fat['BMI'] <= 40]
bmi = smf.ols(formula='Density~BMI+1', data=cfat).fit()
bmi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Density   R-squared:                       0.536
# Model:                            OLS   Adj. R-squared:                  0.534
# Method:                 Least Squares   F-statistic:                     286.2
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           3.25e-43
# Time:                        04:09:46   Log-Likelihood:                 734.17
# No. Observations:                 250   AIC:                            -1464.
# Df Residuals:                     248   BIC:                            -1457.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1602      0.006    186.410      0.000       1.148       1.172
# BMI           -0.0041      0.000    -16.918      0.000      -0.005      -0.004
# ==============================================================================
# Omnibus:                        2.262   Durbin-Watson:                   1.576
# Prob(Omnibus):                  0.323   Jarque-Bera (JB):                2.259
# Skew:                           0.229   Prob(JB):                        0.323
# Kurtosis:                       2.916   Cond. No.                         195.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# tests your bmi model

# %%
p = bmi.params
p.Intercept, p.BMI
# Out:
# (1.1602322201287332, -0.004127636875698844)

# %% [markdown]
# ### 3b. [Peer Review]
# Plot your regression model against the BMI measurement, properly labeling the scatterplot axes and showing the regression line. In subsequent models, you will not be able to plot the Density *vs* your predictors because you will have too many predictors, but it's useful to visually understand the relationship between the BMI predictor and the `Density` because you should find that the regression line goes through the data but there is too much variability in the data to achieve a good $R^2$.
# Upload a copy or screensho of your plot for this week's Peer Review assignment.

# %%
# plot regression model against BMI measurement
# properly label the scatterplot axs and show the regression line
# your code here
# generate x-values for your regression line (two is sufficient)
x = np.arange(50)

# scatter-plot data
ax = cfat.plot(x='BMI', y='Density', kind='scatter')

# plot regression line on the same axes, set x-axis limits
p = bmi.params
ax.plot(x, p.Intercept + p.BMI * x)
ax.set_xlim([0, 50])
plt.title('Density vs. BMI', size=15)
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
#  The `BMI` model uses easy-to-measure predictors, but has a poor $R^2 \sim 0.54$. We will use structured subset selection methods from ISLR Chapter 6.1 to derive two better predictors. That chapter covers *best subset*, *forward stepwise* and *backware stepwise* selection. I have implemented the *best subset* selection which searches across all combinations of $1, 2, \ldots, p$ predictors and selects the best predictor based on the $\textit{adjusted}~R^2$ metric. This method involved analyzing $2^{13} = 8192$ regression models (programming and computers for the win). The resulting $\textit{adjusted}~R^2$ plot is shown below (Since the data split can be different, your result may look slightly different):
#
#  <img src='fat-best-rsqadj.png'>
#
# In this plot, `test_fat` and `train_fat` datasets each containing 200 randomly selected samples were derived from the `cfat` dataset using `np.random.choice` over the `cfat.index` and selected using the Pandas `loc` method. Then, following the algorithm of ISLR Algorithm 6.1 *Best Subset Selection*, all $p \choose k$ models with $k$ predictors were evaluated on the training data and the model returning the best $\textit{Adjusted}~R^2$ was selected. These models are indicated by the data points for the solid blue line. As the text indicates, other measures (AIC, BIC, $C_p$) would be better than the $\textit{Adjusted}~R^2$, but we use it becuase because you've already seen the $R^2$ and should have an understanding of what it means.
#
# Then, the best models for each $k$ were evaluated for the `test_fat` data. These results are shown as the red dots below the blue line. Note that because the test and train datasets are randomly selected subsets, the results vary from run-to-run and it may that your test data produces better $R^2$ than your training data.
#
# In the following exercises, you can not use the `Density`, `Fat` or `BMI` columns in your predictive models. You can only use the 13 predictors in the `allowed_factors` list.

# %%
allowed_factors = ['Age', 'Weight', 'Height', 'Neck', 'Chest',
       'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps', 'Forearm',
       'Wrist']

# %% [markdown]
# ## Forward Stepwise Refinement

# %% [markdown]
# You will manually perform the steps of the *forward stepwise selection* method for four parameters. You will do this following Algorithm 6.2 from ISLR. For $k = 1\ldots 4$:
# * Set up a regression model with $k$ factors that involves the fixed predictors from the previous step $k-1$
# * Try all $p$ predictors in the new $k$th position
# * Select the best parameter using $\textit{Adjusted}-R^2$ (e.g. `model.rsquared_adj`) given your training data
# * Fix the new parameter and continue the process for $k+1$
#
# Then, you will construct a plot similar to the one above, plotting the $\textit{Adjusted}-R^2$ for each of your $k$ steps and plotting the $\textit{Adjusted}-R^2$ from the test set using that model.

# %% [markdown]
# ### 3c. [5 pts]
# First, construct your training and test sets from your `cfat` dataset. Call the resulting data frame to train_fat and test_fat. train_fat includes randomly selected 125 observations and the test_fat has the rest.
#
# Note: Set **random_state = 0** in sklearn's split function

# %%
# construct train_fat and test_fat from cfat dataset 
# your code here
# cfat.shape
#np.random.seed(0)
#train_indices = np.random.choice(cfat.index, 125)
#train_fat = cfat.sample(frac=0.8,random_state=200)
#test=df.drop(train.index)
#train_fat = cfat.loc[train_indices]
#test_fat = cfat.drop(train_fat.index)
#train_indices.shape, cfat.shape, train_fat.shape, test_fat.shape
from sklearn.model_selection import train_test_split
train_fat, test_fat = train_test_split(cfat, test_size=0.5, random_state=0)
#train_fat.shape, test_fat.shape

# %%
# tests your training and test sets

# %%
train_fat.head()
# Out:
#      Density  BodyFat  Age     Weight   Height  Neck  Chest  Abdomen    Hip  \
# 147   1.0322     29.6   25  93.666748  1.77165  40.9  110.9    100.5  106.2
# 217   1.0819      7.5   51  70.079964  1.77800  36.9   93.3     81.5   94.4
# 64    1.0264     32.3   57  93.213156  1.77800  40.1  105.3    105.5  108.3
# 140   1.0422     24.9   40  80.172386  1.80340  37.4   98.6     93.1  101.6
# 192   1.0624     15.9   42  87.770052  1.79070  40.7  104.9     94.1  102.7
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist        BMI
# 147   68.4  40.8   24.6    33.3     29.7   18.4  29.842114
# 217   54.7  39.0   22.6    27.5     25.9   18.6  22.168196
# 64    65.0  41.2   24.7    35.3     31.1   18.4  29.485853
# 140   59.1  39.6   21.6    30.8     27.9   16.6  24.651348
# 192   60.6  38.6   24.7    34.0     30.1   18.7  27.371632

# %% [markdown]
# ### 3d. Conduct the algorithm above for $k=1$, leaving your best solution as the answer [5 pts]
# Call your resulting model `train_bmi1`.

# %%
best = ['',0]
for p in allowed_factors:
    model  = smf.ols(formula='Density~'+p, data=train_fat).fit()
    print(p, model.rsquared)
    if model.rsquared>best[1]:
        best = [p, model.rsquared]
print('best:',best)
# Out:
# Age 0.11891818526391618
# Weight 0.3118316510507485
# Height 0.013604499535144865
# Neck 0.23659704375100143
# Chest 0.4831906740435348
# Abdomen 0.6569981103212714
# Hip 0.30961100444652223
# Thigh 0.20523437265112698
# Knee 0.14348108465750498
# Ankle 0.08478533257962151
# Biceps 0.23065760452385498
# Forearm 0.08974003323360791
# Wrist 0.10016498175577249
# best: ['Abdomen', 0.6569981103212714]

# %%
# uncomment and update your solution 
# train_bmi1 = 

# your code here
train_bmi1 = smf.ols(formula='Density~'+best[0], data=train_fat).fit()
train_bmi1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Density   R-squared:                       0.657
# Model:                            OLS   Adj. R-squared:                  0.654
# Method:                 Least Squares   F-statistic:                     235.6
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           2.32e-30
# Time:                        04:09:56   Log-Likelihood:                 380.21
# No. Observations:                 125   AIC:                            -756.4
# Df Residuals:                     123   BIC:                            -750.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1961      0.009    130.307      0.000       1.178       1.214
# Abdomen       -0.0015   9.85e-05    -15.349      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                       19.876   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.245
# Skew:                           0.686   Prob(JB):                     8.17e-09
# Kurtosis:                       5.296   Cond. No.                         821.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# tests train_bmi1 model

# %% [markdown]
# ### 3e. Conduct the algorithm above for $k=2$, leaving your best solution as the answer [Peer Review]
# Name your model object as `train_bmi2`.<br>
# Look at this week's Peer Review assignment for questions about $k=2$ through $k=5$.

# %%
best = ['', 0]
formulas = []
rsquared_adjs = []
formula1 = 'Density ~ Abdomen'     # k = 1

for p in set(allowed_factors) - set(['Abdomen']):
    formula2 = f'{formula1} + {p}' # k = 2
    formulas.append(formula2)
    model  = smf.ols(formula=formula2, data=train_fat).fit()
    rsquared_adjs.append(model.rsquared_adj)
    if model.rsquared_adj > best[1]:
        best = [p, model.rsquared_adj]
        
# sort models w.r.t. adjusted R2 values
sorted_indices = np.argsort(rsquared_adjs)
print('formula \t\t adjusted-rsquared')
for i in sorted_indices:
    print(formulas[i], rsquared_adjs[i])
print()

print('best:',best)

train_bmi2 = smf.ols(formula=f'{formula1}+{best[0]}', data=train_fat).fit()
train_bmi2.summary()
# Out:
# formula 		 adjusted-rsquared
# Density ~ Abdomen + Biceps 0.6563730451288071
# Density ~ Abdomen + Forearm 0.6700374496099839
# Density ~ Abdomen + Age 0.67149063154188
# Density ~ Abdomen + Chest 0.6750153458293411
# Density ~ Abdomen + Thigh 0.6790054278531203
# Density ~ Abdomen + Ankle 0.6796405857834611
# Density ~ Abdomen + Neck 0.6812956318033548
# Density ~ Abdomen + Knee 0.6888166629829017
# Density ~ Abdomen + Height 0.6907610149384398
# Density ~ Abdomen + Wrist 0.7008314370967657
# Density ~ Abdomen + Hip 0.7206773556849707
# Density ~ Abdomen + Weight 0.7298968547424143
#
# best: ['Weight', 0.7298968547424143]
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Density   R-squared:                       0.734
# Model:                            OLS   Adj. R-squared:                  0.730
# Method:                 Least Squares   F-statistic:                     168.5
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           7.81e-36
# Time:                        04:09:57   Log-Likelihood:                 396.16
# No. Observations:                 125   AIC:                            -786.3
# Df Residuals:                     122   BIC:                            -777.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.2084      0.008    144.306      0.000       1.192       1.225
# Abdomen       -0.0024      0.000    -13.926      0.000      -0.003      -0.002
# Weight         0.0009      0.000      5.955      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                       11.620   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.391
# Skew:                           0.588   Prob(JB):                      0.00124
# Kurtosis:                       4.090   Cond. No.                     1.13e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.13e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### 3f. Conduct the algorithm above for $k=3$, leaving your best solution as the answer [Peer Review]

# %%
# your code here
best = ['',0]
for p in set(allowed_factors) - set(['Abdomen','Weight']):
    model  = smf.ols(formula='Density~1+Abdomen+Weight+'+p, data=train_fat).fit()
    if model.rsquared_adj>best[1]:
        best = [p, model.rsquared_adj]
print('best:',best)
train_bmi3 = smf.ols(formula='Density~1+Abdomen+Weight+'+best[0], data=train_fat).fit()
train_bmi3.summary()
# Out:
# best: ['Biceps', 0.7441772156787975]
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Density   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.744
# Method:                 Least Squares   F-statistic:                     121.2
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           2.64e-36
# Time:                        04:09:57   Log-Likelihood:                 400.07
# No. Observations:                 125   AIC:                            -792.1
# Df Residuals:                     121   BIC:                            -780.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.2348      0.012     98.987      0.000       1.210       1.260
# Abdomen       -0.0024      0.000    -14.529      0.000      -0.003      -0.002
# Weight         0.0012      0.000      6.548      0.000       0.001       0.002
# Biceps        -0.0014      0.001     -2.795      0.006      -0.002      -0.000
# ==============================================================================
# Omnibus:                        6.462   Durbin-Watson:                   1.794
# Prob(Omnibus):                  0.040   Jarque-Bera (JB):                5.977
# Skew:                           0.480   Prob(JB):                       0.0504
# Kurtosis:                       3.477   Cond. No.                     1.79e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.79e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### 3g. Conduct the algorithm above for $k=4$, leaving your best solution as the answer [Peer Review]

# %%
# your code here

best = ['',0]
for p in set(allowed_factors) - set(['Abdomen','Weight', 'Biceps']):
    model  = smf.ols(formula='Density~1+Abdomen+Weight+Biceps+'+p, data=train_fat).fit()
    if model.rsquared_adj>best[1]:
        best = [p, model.rsquared_adj]
print('best:',best)
train_bmi4 = smf.ols(formula='Density~1+Abdomen+Weight+Biceps+'+best[0], data=train_fat).fit()
train_bmi4.summary()
# Out:
# best: ['Wrist', 0.7506001901244438]
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Density   R-squared:                       0.759
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     94.30
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           4.24e-36
# Time:                        04:09:58   Log-Likelihood:                 402.18
# No. Observations:                 125   AIC:                            -794.4
# Df Residuals:                     120   BIC:                            -780.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1948      0.023     51.329      0.000       1.149       1.241
# Abdomen       -0.0024      0.000    -14.362      0.000      -0.003      -0.002
# Weight         0.0010      0.000      5.092      0.000       0.001       0.001
# Biceps        -0.0016      0.001     -3.068      0.003      -0.003      -0.001
# Wrist          0.0030      0.001      2.029      0.045    7.19e-05       0.006
# ==============================================================================
# Omnibus:                        3.832   Durbin-Watson:                   1.816
# Prob(Omnibus):                  0.147   Jarque-Bera (JB):                3.311
# Skew:                           0.380   Prob(JB):                        0.191
# Kurtosis:                       3.240   Cond. No.                     3.41e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### 3h. Conduct the algorithm above for $k=5$, leaving your best solution as the answer [Peer Review]

# %%
# forward stepwise regression: from k = 4 to k = 5 
best = ['',0]
formulas = []
rsquared_adjs = []
formula4 = 'Density ~ Abdomen + Weight + Biceps + Wrist'     # k = 4

for p in set(allowed_factors) - set(['Abdomen','Weight', 'Biceps', 'Wrist']):
    formula5 = f'{formula4} + {p}' # k = 5
    formulas.append(formula5)
    model  = smf.ols(formula=formula5, data=train_fat).fit()
    rsquared_adjs.append(model.rsquared_adj)
    if model.rsquared_adj > best[1]:
        best = [p, model.rsquared_adj]

# sort models w.r.t. adjusted R2 values
sorted_indices = np.argsort(rsquared_adjs)
print('formula \t\t\t\t\t\t adjusted-rsquared')
for i in sorted_indices:
    print(formulas[i], rsquared_adjs[i])
print()

print('best:',best)

train_bmi5 = smf.ols(formula='Density~1+Abdomen+Weight+Biceps+Wrist+'+best[0], data=train_fat).fit()
train_bmi5.summary()
# Out:
# formula 						 adjusted-rsquared
# Density ~ Abdomen + Weight + Biceps + Wrist + Forearm 0.7485045995598735
# Density ~ Abdomen + Weight + Biceps + Wrist + Thigh 0.7485504428524089
# Density ~ Abdomen + Weight + Biceps + Wrist + Knee 0.7488614496333049
# Density ~ Abdomen + Weight + Biceps + Wrist + Age 0.7494193480231307
# Density ~ Abdomen + Weight + Biceps + Wrist + Chest 0.7499372263498394
# Density ~ Abdomen + Weight + Biceps + Wrist + Neck 0.7502556901314873
# Density ~ Abdomen + Weight + Biceps + Wrist + Height 0.7511576108898333
# Density ~ Abdomen + Weight + Biceps + Wrist + Ankle 0.7528723602513581
# Density ~ Abdomen + Weight + Biceps + Wrist + Hip 0.7578732528786728
#
# best: ['Hip', 0.7578732528786728]
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Density   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     78.63
# Date:                Tue, 14 Nov 2023   Prob (F-statistic):           4.67e-36
# Time:                        04:09:58   Log-Likelihood:                 404.55
# No. Observations:                 125   AIC:                            -797.1
# Df Residuals:                     119   BIC:                            -780.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1362      0.036     31.887      0.000       1.066       1.207
# Abdomen       -0.0025      0.000    -14.673      0.000      -0.003      -0.002
# Weight         0.0006      0.000      2.147      0.034     4.5e-05       0.001
# Biceps        -0.0015      0.001     -3.030      0.003      -0.003      -0.001
# Wrist          0.0038      0.001      2.522      0.013       0.001       0.007
# Hip            0.0008      0.000      2.146      0.034    6.48e-05       0.002
# ==============================================================================
# Omnibus:                        6.193   Durbin-Watson:                   1.808
# Prob(Omnibus):                  0.045   Jarque-Bera (JB):                5.809
# Skew:                           0.432   Prob(JB):                       0.0548
# Kurtosis:                       3.606   Cond. No.                     6.70e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.7e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### 3i. Plot [5 pts]
# Plot your resulting $\textit{adjusted}~R^2$ *vs* number of predictors (k=1,2,3,4,5) and overlay the $\textit{adjusted}~R^2$ for the test data. Call the list of the five adjusted r-squared values from the five train_bmi# models as `adjr2_train` and the one from the test data as `adjr2_test`.

# %%
models = [train_bmi1, train_bmi2, train_bmi3, train_bmi4, train_bmi5]
N = len(test_fat)
SST = np.sum((test_fat['Density'] - np.mean(train_fat['Density']))**2)
adjr2_test = []
for p in range(1, 6):
    SSR = np.sum((test_fat['Density'] - models[p-1].predict(test_fat))**2)
    R2 = 1 - SSR / SST
    adjr2_test.append(1 - (1-R2)*(N-1) / (N - p - 1))

# %%
# plot resulting adjusted rsquared vs number of predictors (k=1,2,3,4,5)
# overlay the adjusted rsquared for the test data 
# your code here
adjr2_train = [train_bmi1.rsquared_adj, train_bmi2.rsquared_adj, train_bmi3.rsquared_adj, train_bmi4.rsquared_adj, train_bmi5.rsquared_adj]
adjr2_train, adjr2_test
plt.figure(figsize=(10,10))
plt.plot(range(1,6), adjr2_train, 'b.-', label=r'adj $R^2$ train', markersize=20)
plt.plot(range(1,6), adjr2_test, 'r.-', label=r'adj $R^2$ test', markersize=20)
plt.xticks(range(1,6))
plt.xlabel(r'$k$', size=20)
plt.ylabel(r'adjusted $R^2$', size=20)
plt.title(r'Adjusted $R^2$', size=25)
plt.legend()
plt.show()

# %%
#SSR = np.sum((train_fat['Density'] - train_bmi5.predict(train_fat))**2)
#SST = np.sum((train_fat['Density'] - np.mean(train_fat['Density']))**2)
#R2 = 1 - SSR / SST
#N, p = len(train_fat), 5
#1 - (1-R2)*(N-1) / (N - p - 1)

# %%
# tests adjusted r-squared plot vs. number of factors

# %% [markdown]
# ### 3j. Discussion [Peer Review]
# The BMI model has the benefit being simple (two measurements, height and wright). Looking at your resulting regression model, how many parameters would you suggest to use for your enhanced BMI model? Justify your answer using your models. Submit your answer with this week's Peer Review assignment.
