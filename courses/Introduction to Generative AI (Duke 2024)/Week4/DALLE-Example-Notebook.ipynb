# %% [markdown]
# ## Example Notebook with all of the Code from the Lecture (Just Needs an API Key)

# %%
# Making sure OpenAI is install
# !pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\hp\anaconda3\lib\site-packages (1.37.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\hp\anaconda3\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\hp\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\anaconda3\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\hp\anaconda3\lib\site-packages (from openai) (2.5.3)
# Requirement already satisfied: sniffio in c:\users\hp\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\hp\anaconda3\lib\site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\hp\anaconda3\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hp\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\hp\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.14.6)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
# Bringing in Libraries
import os
import openai

os.environ["OPENAI_API_KEY"] = "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"
openai.api_key=os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ### Add API key below and delete cell after running

# %%
# os.environ["OPENAI_API_KEY"] = "YOUR KEY GOES HERE"
# openai.api_key=os.getenv('OPENAI_API_KEY')

# %%
from openai import OpenAI
client = OpenAI()

# %%
# Create shopping list and recipe function
def create_shopping_list(recipe):
    prompt = f"Create a shopping list based on the following reciepe and goods that go well with it and cooking instructions: {(recipe)}"

    return prompt

# %%
# Function Test
recipe = create_shopping_list("Chipotle chicken and rice bowl")

print(recipe)
# Out:
# Create a shopping list based on the following reciepe and goods that go well with it and cooking instructions: Chipotle chicken and rice bowl

# %% [markdown]
# ###  Remember this will be using your tokens to running repeated could result in fees

# %%
# Receaching out to OpenAI for the answer
response = client.chat.completions.create(
    model = "gpt-3.5-turbo",
    messages = [
        {
            "role":"system",
            "content": recipe
        },
    ],
    temperature = 0.7, ### Feel free to change hyperparameters
    top_p = 1,
)

print(response.choices[0].message.content)
# Out:
# Shopping list:
# 1. Chicken breasts
# 2. Chipotle peppers in adobo sauce
# 3. Long grain white rice
# 4. Black beans
# 5. Corn
# 6. Red bell pepper
# 7. Avocado
# 8. Lime
# 9. Cilantro
# 10. Olive oil
# 11. Salt
# 12. Pepper
#
# Cooking instructions:
# 1. Cook the rice according to package instructions.
# 2. Season the chicken breasts with salt and pepper, then grill or pan-sear until fully cooked.
# 3. In a blender, blend chipotle peppers in adobo sauce with olive oil to make a marinade.
# 4. Slice the cooked chicken and toss it in the chipotle marinade.
# 5. In a separate pan, heat black beans, corn, and diced red bell pepper until heated through.
# 6. Assemble the bowls by layering rice, chipotle chicken, black bean/corn mixture, sliced avocado, and a squeeze of lime juice.
# 7. Garnish with chopped cilantro and serve hot. Enjoy your delicious Chipotle chicken and rice bowl!

# %%
# Putting the ingredients into a shopping list
import re

text = response.choices[0].message.content

pattern = re.compile(r'\d+\. (.+)')
matches = pattern.findall(text)

shopping_list = []

for match in matches:
    shopping_list.append(match)

print(shopping_list)
# Out:
# ['Chicken breasts', 'Chipotle peppers in adobo sauce', 'Long grain white rice', 'Black beans', 'Corn', 'Red bell pepper', 'Avocado', 'Lime', 'Cilantro', 'Olive oil', 'Salt', 'Pepper', 'Cook the rice according to package instructions.', 'Season the chicken breasts with salt and pepper, then grill or pan-sear until fully cooked.', 'In a blender, blend chipotle peppers in adobo sauce with olive oil to make a marinade.', 'Slice the cooked chicken and toss it in the chipotle marinade.', 'In a separate pan, heat black beans, corn, and diced red bell pepper until heated through.', 'Assemble the bowls by layering rice, chipotle chicken, black bean/corn mixture, sliced avocado, and a squeeze of lime juice.', 'Garnish with chopped cilantro and serve hot. Enjoy your delicious Chipotle chicken and rice bowl!']

# %%
# Sending the item to DALLE 
image_response = client.images.generate(
    model ="dall-e-3",
    prompt=shopping_list[0],
    size="1024x1024",
    quality="standard",
    n=1,
)

image_url = image_response.data[0].url 

print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-1fVJgtDr6ouX6qC0qcFWvFVq/user-0rtsSguuZAtnU2CyPmynvnfS/img-nHNLwrd3LZ1bVRBLtxm5yK2q.png?st=2024-08-11T18%3A22%3A27Z&se=2024-08-11T20%3A22%3A27Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-08-11T05%3A40%3A58Z&ske=2024-08-12T05%3A40%3A58Z&sks=b&skv=2023-11-03&sig=26BScTyMysYvqC835t77T7hr7RsHFcV79T4roNKmfwA%3D

# %% [markdown]
# ![](img-nHNLwrd3LZ1bVRBLtxm5yK2q.png)

# %%
#from openai import OpenAI
#client = OpenAI()

audio_file = open("openai_sandipan.m4a", "rb")
transcription = client.audio.transcriptions.create(
  model="whisper-1", 
  file=audio_file, 
  response_format="text"
)
print(transcription)
# Out:
# Hi, this is Sandy Pan. I am a data scientist and a machine learning and deep learning enthusiast. I have written a few books on image processing and computer vision. I am a research enthusiast as well.
