# %% [markdown]
# # Bootstrapping

# %%
# Standard imports
import matplotlib.pyplot as plt
import numpy as np

# Dataset 
from sklearn.datasets import load_wine

# For computing bootstrapping for a linear regression model
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Load the wine dataset
wine = load_wine()
X, y = wine.data, wine.target

# %%
# Number of bootstrap iterations
num_rounds = 1000

lambdas = np.arange(0.0001, 0.001, 0.0001)
mean_mse_scores = []
mean_mse_CIs = []
mean_r2_scores = []
mean_r2_CIs = []

# loop through potential lambda values 
#for lam in lambdas:

    # Create a Lasso regression model with lam
    
    # Lists to store bootstrapped scores
    
    # Perform bootstrapping
    
        # Generate random indices with replacement
        
    
        # Fit the model and make predictions
        
    
        # Calculate mean squared error and R-squared

    # Calculate bootstrapped mean and confidence intervals for MSE and R-squared and save
    
# Print the best lambda based on the lowest mean MSE. 
# print the lowest mean MSE, its confidence interval, the associated R^2 and its confidence interval

# %%
# Plot the mean R-squared scores versus the lambda values

# Plot the mean MSE scores versus the lambda values

# %%
# Write the final model and its coefficients

# %% [markdown]
# # Write Up
#
# Write a blurb discussing your work above.
