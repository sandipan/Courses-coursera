# %% [markdown]
# # Smoothing Splines

# %%
# Standard imports
import numpy as np
import matplotlib.pyplot as plt

# For modeling and evaluation

# %%
# Example data: noisy sine wave
np.random.seed(9) 
# Define the data points and intervals
X = np.linspace(0, 6, 500)  # 500 points spanning [0, 6]
Y = np.cos(X)**3 + 2*np.sin(X)**2 + np.random.normal(0, 0.5, 500)  # Generate noisy data

# Split the data into training, validation, and testing sets, random_state = 9

# Add other np arrays

# Sort to ensure strictly increasing x values

# %%
# Plotting the original data

# %%
# Initialize hyperparameter candidates and corresponding MSE and R-squared values

# Iterate through different values of s and calculate MSE and R-squared on the validation set


# Find the value of s that minimizes the MSE on the validation set

# Create the final smoothing spline model using the best s

# Predict on test set

# Calculate MSE and R-squared for the test set

# Plot s values against MSE and R-squared on the validation set


# Plot the data and the final smoothing spline


# Print evaluation metrics for the test set

# %%
# Explore other smoothing spline models (optional)

# %% [markdown]
# ## Write Up
#
# Write a blurb describing your work above.
