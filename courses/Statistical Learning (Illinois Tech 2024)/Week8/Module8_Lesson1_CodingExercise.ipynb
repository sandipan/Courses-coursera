# %% [markdown]
# # Tree Models with Wine Dataset

# %%
# Standard imports
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Dataset
from sklearn.datasets import load_wine

# For model and evaluation
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Load the Wine dataset
data = load_wine()
X = data.data
y = data.target

# Split the data into training, validation, and testing sets

# %%
depths = list(range(1, 25))
accuracies = []

# find the optimal depth using the validation set.

# %%
# Plot the depth vs. validation set metrics

# %%
# Create the final decision tree classifier model


# Visualize the decision tree

# %%
# Make classification report

# %%
# Calculate and display the confusion matrix

# %% [markdown]
# # Write Up
#
# Write a description of your findings above.
