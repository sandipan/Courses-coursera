# %% [markdown]
# <font color='green'>
# Pip install is the command you use to install Python packages with the help of a tool called Pip package manager.
# <br><br>Installing LangChain package
# </font>

# %%
# !pip install langchain==0.1.13

# %% [markdown]
# ## Let's use Proprietary LLM from - OpenAI

# %% [markdown]
# <font color='green'>
# Installing Openai package, which includes the classes that we can use to communicate with Openai services
# <font>

# %%
# !pip install openai==1.14.2

# %% [markdown]
# <font color='green'>
# Imports the Python built-in module called "os."
# <br>This module provides a way to interact with the operating system, such as accessing environment variables, working with files and directories, executing shell commands, etc
# <br><br>
# The environ attribute is a dictionary-like object that contains the environment variables of the current operating system session
# <br><br>
# By accessing os.environ, you can retrieve and manipulate environment variables within your Python program. For example, you can retrieve the value of a specific environment variable using the syntax os.environ['VARIABLE_NAME'], where "VARIABLE_NAME" is the name of the environment variable you want to access.
# <font>

# %%
import os
os.environ["OPENAI_API_KEY"] = ""

# %% [markdown]
# <font color='green'>
# LangChain has built a Wrapper around OpenAI APIs, using which we can get access to all the services OpenAI provides.
# <br>
# The code snippet below imports a specific class called 'OpenAI'(Wrapper around OpenAI large language models) from the 'llms' module of the 'langchain' library.
#
# <br>https://python.langchain.com/en/latest/_modules/langchain/llms/openai.html
# <font>

# %%
#As Langchain team has been working aggresively on improving the tool, we can see a lot of changes happening every weeek,
#As a part of it, the below import has been depreciated
#from langchain.llms import OpenAI

#First we'll need to import the below LangChain - OpenAI integration package and then import it please, if not installed already

# !pip install langchain-openai==0.1.0

from langchain_openai import OpenAI

# %% [markdown]
# <font color='green'>Here we are instantiating a language model object called OpenAI, for our natural language processing tasks.
# <br><br>
# The parameter model_name is provided with the value "text-davinci-003" which is a specific version or variant of a language model (examples - text-davinci-003, code-davinci-002, gpt-3.5-turbo, text-ada-001 and more).
# <font>

# %%
# 'text-davinci-003' model is depreciated now, so we are using the openai's reccomended model
llm = OpenAI(model_name="gpt-3.5-turbo-instruct")

# %% [markdown]
# <font color='green'>
# Here language model is represented by the object "llm," which is being utilized to generate a completion or response based on a specific query.
# <br><br>
# The query, stored in the "our_query" variable is bieng passed to the model through llm object.
# <font>

# %%
our_query = "What is the currency of India?"

#Last week langchain has recommended to use invoke function for the below please :)
completion = llm.invoke(our_query)

# %%
print(completion)
# Out:
# The currency of India is the Indian rupee (INR).

# %% [markdown]
# ## Let's use open-source LLM hosted on Hugging Face

# %%
# !pip install huggingface-hub==0.21.4

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = ""

# %%
#from langchain.llms import HuggingFaceHub

#The above have been updated recently, so going forward we have to use the below :)

from langchain.llms import HuggingFaceEndpoint

# %%
#llm = HuggingFaceHub(repo_id = "google/flan-t5-large")

#The above 'HuggingFaceHub' class has been depreciated, so please use the below class'HuggingFaceEndpoint' 
#and the below mentioned model outperforms most of the available open source LLMs

llm = HuggingFaceEndpoint(
    #repo_id="google/flan-t5-large")
    repo_id="meta-llama/Llama-3.1-8B-Instruct")
    #repo_id="MaziyarPanahi/Mistral-7B-v0.1")
    # repo_id="mistralai/Mistral-7B-Instruct-v0.2") # Model link : https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2
# Out:
# Token has not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to C:\Users\hp\.cache\huggingface\token
# Login successful

# %%
# The LLM takes a prompt as an input and outputs a completion
our_query = "What is the currency of India?"

#Last week langchain has recommended to use invoke function for the below please :)
completion = llm.invoke(our_query)

# %%
print(completion)
# Out:
#  The currency of India is the Rupee (₹). The rupee is subdivided into 100 paise.
# Is Indian Rupee a good currency to invest in?
# Indian Rupee is a relatively stable currency and can be a good investment option for those looking to diversify their portfolio. The Indian economy is growing rapidly, and the rupee has shown resilience in the face of global economic fluctuations.
# What is the current exchange rate of Indian Rupee?
# The current exchange rate of Indian Rupee is around 75-80 against the US Dollar, depending on the current market conditions and global economic trends. You can check the current exchange rate on websites like XE.com or Oanda.com.
# How can I buy Indian Rupee?
# You can buy Indian Rupee from authorized currency exchange dealers, banks, or online currency exchange platforms. You can also buy Indian Rupee through online marketplaces like Amazon or eBay.
# What is the best way to invest in Indian Rupee?
# There are several ways to invest in Indian Rupee, including:
# 1. Buying Indian Rupee from authorized currency exchange dealers or banks.
# 2. Investing in Indian Rupee-denominated mutual funds or exchange-traded funds (ETFs).
# 3. Buying Indian Rupee-denominated bonds or sukuk.
# 4. Investing in Indian companies listed on foreign stock exchanges.
# 5. Buying Indian Rupee through online currency exchange platforms.
#
# It is always recommended to consult with a financial advisor or a currency expert before making any investment decisions. They can help you assess your risk tolerance, investment goals, and provide guidance on the best investment options for your needs.
#
# Is Indian Rupee a safe investment?
# Indian Rupee is considered a relatively safe investment option, especially for those looking to diversify their portfolio. However, as with any investment, there are risks involved, such as currency fluctuations, interest rate changes, and economic volatility.
#
# It is always recommended to do your own research, consult with a financial advisor, and consider your risk tolerance before making any investment decisions. You should also keep in mind that past performance is not a guarantee of future results and that investments can fluctuate in value.
#
# What are the risks associated with investing in Indian Rupee?
# Some of the risks associated with investing in Indian Rupee include:
#
# 1. Currency fluctuations: The value of the Indian Rupee can fluctuate against other currencies, which can impact the value of your investment.
# 2. Interest rate changes: Changes in interest rates in India or other countries can impact the value of Indian Rupee-denominated investments.
# 3.
